# %% [markdown]
# # Most Dangerous Streets - Crash Leaderboard
#
# Compare the most recent month to the all-time numbers to see which streets got safer.

# %%
import pytz
import folium
import pandas as pd
from datetime import datetime, timedelta

import os
os.chdir('..')
from scripts.crash_data_analysis import CrashDataAnalysis

# %%
cda = CrashDataAnalysis()

# %%
start_date = pytz.timezone('America/Denver').localize(datetime(2020,7,1))
end_date = cda.most_recent_crash_timestamp()

all_time = cda.street_metrics(start_date, end_date)

# %%
start_date = pytz.timezone('America/Denver').localize(datetime(2025,6,1))
end_date = pytz.timezone('America/Denver').localize(datetime(2025,7,1))

last_month = cda.street_metrics(start_date, end_date)

# %%
# A street must have at least 100 crashes all-time to be in the comparison
all_time = all_time[all_time.num_crashes >= 100].copy()

# %%
all_time
# Out:
#        gid      lrsroute      fullname street_name_no_cardinal  length_miles
# 1793  3900   SPEERN   BD  N SPEER BLVD              SPEER BLVD      2.634723  \
# 831   1452   ESPEERN  BD  E SPEER BLVD              SPEER BLVD      1.060124
# 2696  5587   PARK     AV    PARK AVE W              PARK AVE W      1.809664
# 1990  4229   22ND     ST       22ND ST                 22ND ST      1.079568
# 1986  4225   20TH     ST       20TH ST                 20TH ST      1.453330
# ...    ...           ...           ...                     ...           ...
# 3167  6778  SZUNI    ST2     S ZUNI ST                 ZUNI ST      2.981573
# 313    494  48TH     AV6    E 48TH AVE                48TH AVE      2.758182
# 950   1661  HOLLY    ST1    N HOLLY ST                HOLLY ST      3.763453
# 2819  6066  SMITH    RD1    E SMITH RD                SMITH RD      2.852613
# 19      34  29TH     AV1    E 29TH AVE                29TH AVE      3.723713
#
#                                             street_line  num_crashes  num_sbi
# 1793  {"type":"MultiLineString","coordinates":[[[-10...         1149       35  \
# 831   {"type":"MultiLineString","coordinates":[[[-10...          357        9
# 2696  {"type":"MultiLineString","coordinates":[[[-10...          605       23
# 1990  {"type":"MultiLineString","coordinates":[[[-10...          353       10
# 1986  {"type":"MultiLineString","coordinates":[[[-10...          467       12
# ...                                                 ...          ...      ...
# 3167  {"type":"MultiLineString","coordinates":[[[-10...          111        4
# 313   {"type":"MultiLineString","coordinates":[[[-10...          101        3
# 950   {"type":"MultiLineString","coordinates":[[[-10...          136        0
# 2819  {"type":"MultiLineString","coordinates":[[[-10...          103        4
# 19    {"type":"MultiLineString","coordinates":[[[-10...          110        2
#
#       num_fatality  num_sbi_or_fatality  sum_bicycle_ind  sum_pedestrian_ind
# 1793             8                   43             18.0                37.0  \
# 831              2                   11              5.0                 6.0
# 2696             2                   25             12.0                24.0
# 1990             2                   12              6.0                19.0
# 1986             1                   13              8.0                31.0
# ...            ...                  ...              ...                 ...
# 3167             1                    5              0.0                 4.0
# 313              3                    6              0.0                10.0
# 950              0                    0              2.0                 2.0
# 2819             0                    4              2.0                 2.0
# 19               1                    3              1.0                 5.0
#
#       days_in_data  days_between_crashes  crashes_per_mile_per_week
# 1793          1848              1.608355                   1.651890  \
# 831           1848              5.176471                   1.275580
# 2696          1848              3.054545                   1.266349
# 1990          1848              5.235127                   1.238571
# 1986          1848              3.957173                   1.217163
# ...            ...                   ...                        ...
# 3167          1848             16.648649                   0.141018
# 313           1848             18.297030                   0.138706
# 950           1848             13.588235                   0.136883
# 2819          1848             17.941748                   0.136770
# 19            1848             16.800000                   0.111895
#
#       pedestrian_ind_per_mile_per_year
# 1793                          2.775588
# 831                           1.118621
# 2696                          2.621208
# 1990                          3.478500
# 1986                          4.215856
# ...                                ...
# 3167                          0.265157
# 313                           0.716581
# 950                           0.105034
# 2819                          0.138572
# 19                            0.265388
#
# [196 rows x 16 columns]

# %%
comparison = pd.merge(
    all_time
    , last_month
    , how='inner'
    , on=['gid', 'lrsroute', 'fullname', 'length_miles','street_line']
    , suffixes=['_all_time', '_last_month']
)

# %%
comparison['diff_pmpw'] = (
    comparison['crashes_per_mile_per_week_last_month']
    - comparison['crashes_per_mile_per_week_all_time']
)

# %%
comparison['expected_crashes'] = (
    comparison['length_miles']
    * comparison['crashes_per_mile_per_week_all_time']
    * (comparison['days_in_data_last_month'] / 7)
)

comparison['diff_expected_crashes'] = comparison['num_crashes_last_month'] - comparison['expected_crashes']

# %% [markdown]
# ## Difference in Crash Rate per Mile

# %%
this_map = folium.Map(prefer_canvas=True, tiles='CartoDB Positron')

good_streets = comparison.sort_values(by='diff_pmpw').head(5)['street_line']
bad_streets = comparison.sort_values(by='diff_pmpw').tail(5)['street_line']

for good_street in good_streets:
    folium.GeoJson(good_street, style_function=lambda x: {'color': 'green'}).add_to(this_map)

for bad_street in bad_streets:
    folium.GeoJson(bad_street, style_function=lambda x: {'color': 'red'}).add_to(this_map)
    
this_map.fit_bounds(this_map.get_bounds())
this_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_454883b20a36636e4d84859f5c50c59a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_454883b20a36636e4d84859f5c50c59a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_454883b20a36636e4d84859f5c50c59a = L.map(
#                 &quot;map_454883b20a36636e4d84859f5c50c59a&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d77b78b670bf958cecba7ba1fdba2c40 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_454883b20a36636e4d84859f5c50c59a);
#
#
#         function geo_json_5b1caf0f24c106a429d7364439cb3442_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;};
#             }
#         }
#
#         function geo_json_5b1caf0f24c106a429d7364439cb3442_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_5b1caf0f24c106a429d7364439cb3442 = L.geoJson(null, {
#                 onEachFeature: geo_json_5b1caf0f24c106a429d7364439cb3442_onEachFeature,
#
#                 style: geo_json_5b1caf0f24c106a429d7364439cb3442_styler,
#         });
#
#         function geo_json_5b1caf0f24c106a429d7364439cb3442_add (data) {
#             geo_json_5b1caf0f24c106a429d7364439cb3442
#                 .addData(data)
#                 .addTo(map_454883b20a36636e4d84859f5c50c59a);
#         }
#             geo_json_5b1caf0f24c106a429d7364439cb3442_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-104.968461561, 39.740011143], [-104.969711421, 39.740918603], [-104.970187944, 39.741310923], [-104.970616618, 39.741641599], [-104.970918859, 39.741880765], [-104.971642773, 39.74243616], [-104.972128936, 39.742808266], [-104.972688443, 39.743240065], [-104.972741475, 39.743281142], [-104.973383171, 39.743779532], [-104.973551364, 39.743906905], [-104.973980769, 39.744232088], [-104.97407019, 39.74429983], [-104.974777281, 39.744835486], [-104.976141771, 39.745908485], [-104.976486673, 39.746179702], [-104.976993306, 39.746555996], [-104.977544158, 39.746964395], [-104.978177635, 39.747500819]]], &quot;type&quot;: &quot;MultiLineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_05a5a3eb17e4d81c04b877dbaf88fa87_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;};
#             }
#         }
#
#         function geo_json_05a5a3eb17e4d81c04b877dbaf88fa87_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_05a5a3eb17e4d81c04b877dbaf88fa87 = L.geoJson(null, {
#                 onEachFeature: geo_json_05a5a3eb17e4d81c04b877dbaf88fa87_onEachFeature,
#
#                 style: geo_json_05a5a3eb17e4d81c04b877dbaf88fa87_styler,
#         });
#
#         function geo_json_05a5a3eb17e4d81c04b877dbaf88fa87_add (data) {
#             geo_json_05a5a3eb17e4d81c04b877dbaf88fa87
#                 .addData(data)
#                 .addTo(map_454883b20a36636e4d84859f5c50c59a);
#         }
#             geo_json_05a5a3eb17e4d81c04b877dbaf88fa87_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-105.003224738, 39.748502998], [-105.003117893, 39.748662491], [-105.003068763, 39.748716611], [-105.002775361, 39.748841649], [-105.002611066, 39.748940476], [-105.002506339, 39.749039547], [-105.002211085, 39.749550288], [-105.001241161, 39.750286714], [-105.000025309, 39.751219404], [-104.998809248, 39.752176098], [-104.997624621, 39.753085216], [-104.996412226, 39.75401754], [-104.995147918, 39.754993552]]], &quot;type&quot;: &quot;MultiLineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_c8ed146d98406ddd846d5d69c20f5ea0_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;};
#             }
#         }
#
#         function geo_json_c8ed146d98406ddd846d5d69c20f5ea0_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c8ed146d98406ddd846d5d69c20f5ea0 = L.geoJson(null, {
#                 onEachFeature: geo_json_c8ed146d98406ddd846d5d69c20f5ea0_onEachFeature,

# %%
comparison.sort_values(by='diff_pmpw')[[
    'gid'
    , 'fullname'
    , 'length_miles'
    , 'crashes_per_mile_per_week_all_time'
    , 'crashes_per_mile_per_week_last_month'
    , 'diff_pmpw'
    , 'num_crashes_all_time'
    , 'num_crashes_last_month'
    , 'expected_crashes'
    , 'diff_expected_crashes'
]]
# Out:
#      gid           fullname  length_miles  crashes_per_mile_per_week_all_time
# 11  5372           PARK AVE      0.731422                            1.103082  \
# 10  3811           WAZEE ST      0.624810                            1.109428
# 34  4552       LEETSDALE DR      2.002250                            0.802128
# 13  5579         N OSAGE ST      0.554444                            1.038442
# 1   1452       E SPEER BLVD      1.060124                            1.275580
# ..   ...                ...           ...                                 ...
# 65  4224            19TH ST      0.812553                            0.540757
# 23  2941         N TOWER RD      1.027545                            0.910526
# 39  4220            18TH ST      0.843447                            0.718552
# 53   156          E 1ST AVE      1.225738                            0.621147
# 31  3393  N UNIVERSITY BLVD      0.662389                            0.817748
#
#     crashes_per_mile_per_week_last_month  diff_pmpw  num_crashes_all_time
# 11                              0.319013  -0.784068                   213  \
# 10                              0.373447  -0.735981                   183
# 34                              0.116536  -0.685592                   424
# 13                              0.420842  -0.617600                   152
# 1                               0.660300  -0.615280                   357
# ..                                   ...        ...                   ...
# 65                              1.435804   0.895047                   116
# 23                              2.043707   1.133181                   247
# 39                              1.936498   1.217946                   160
# 53                              1.903615   1.282468                   201
# 31                              2.113563   1.295815                   143
#
#     num_crashes_last_month  expected_crashes  diff_expected_crashes
# 11                       1          3.457792              -2.457792
# 10                       1          2.970779              -1.970779
# 34                       1          6.883117              -5.883117
# 13                       1          2.467532              -1.467532
# 1                        3          5.795455              -2.795455
# ..                     ...               ...                    ...
# 65                       5          1.883117               3.116883
# 23                       9          4.009740               4.990260
# 39                       7          2.597403               4.402597
# 53                      10          3.262987               6.737013
# 31                       6          2.321429               3.678571
#
# [186 rows x 10 columns]

# %% [markdown]
# ## Difference in Number of Expected Crashes

# %%
this_map = folium.Map(prefer_canvas=True, tiles='CartoDB Positron')

good_streets = comparison.sort_values(by='diff_expected_crashes').head(5)['street_line']
bad_streets = comparison.sort_values(by='diff_expected_crashes').tail(5)['street_line']

for good_street in good_streets:
    folium.GeoJson(good_street, style_function=lambda x: {'color': 'green'}).add_to(this_map)

for bad_street in bad_streets:
    folium.GeoJson(bad_street, style_function=lambda x: {'color': 'red'}).add_to(this_map)
    
this_map.fit_bounds(this_map.get_bounds())
this_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea630517a1831479c1683cf30312a774 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea630517a1831479c1683cf30312a774&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea630517a1831479c1683cf30312a774 = L.map(
#                 &quot;map_ea630517a1831479c1683cf30312a774&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2fea8a6eaae50101f7ddb231d3db84c9 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ea630517a1831479c1683cf30312a774);
#
#
#         function geo_json_135d8b5222927dfe5c7aa5f1dc19e4f3_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;};
#             }
#         }
#
#         function geo_json_135d8b5222927dfe5c7aa5f1dc19e4f3_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_135d8b5222927dfe5c7aa5f1dc19e4f3 = L.geoJson(null, {
#                 onEachFeature: geo_json_135d8b5222927dfe5c7aa5f1dc19e4f3_onEachFeature,
#
#                 style: geo_json_135d8b5222927dfe5c7aa5f1dc19e4f3_styler,
#         });
#
#         function geo_json_135d8b5222927dfe5c7aa5f1dc19e4f3_add (data) {
#             geo_json_135d8b5222927dfe5c7aa5f1dc19e4f3
#                 .addData(data)
#                 .addTo(map_ea630517a1831479c1683cf30312a774);
#         }
#             geo_json_135d8b5222927dfe5c7aa5f1dc19e4f3_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-105.025077836, 39.716641515], [-105.025094715, 39.715723286], [-105.025094424, 39.714978626], [-105.025087463, 39.714825206], [-105.025082079, 39.713389051], [-105.025082066, 39.712996821], [-105.025092623, 39.711174677], [-105.025091237, 39.709409795], [-105.025089186, 39.708531635], [-105.025084988, 39.707591233], [-105.025089808, 39.706732786], [-105.025102171, 39.70569374], [-105.025099461, 39.704913034], [-105.025083777, 39.703948002], [-105.025084117, 39.703110001], [-105.025083095, 39.702079135], [-105.025078371, 39.701333427], [-105.025080162, 39.700412041], [-105.025080165, 39.699230531], [-105.025081819, 39.698591914], [-105.025080662, 39.697581639], [-105.025059103, 39.696747281], [-105.025067069, 39.694918802], [-105.025063678, 39.693109461], [-105.025062031, 39.691297473], [-105.025059367, 39.690805257], [-105.025057609, 39.68948645], [-105.025051252, 39.687680299], [-105.025052612, 39.686867958], [-105.025054255, 39.685886085], [-105.025044031, 39.684972343], [-105.02504237, 39.684078957], [-105.025037985, 39.682270753], [-105.02503027, 39.68050941], [-105.025057703, 39.678637154], [-105.025044019, 39.676766472], [-105.025066447, 39.675132404], [-105.025072791, 39.673340242], [-105.025076969, 39.672512505], [-105.025069371, 39.672149681], [-105.025061773, 39.671786855], [-105.025060048, 39.67119626], [-105.02507682, 39.670153789], [-105.025073142, 39.668542562], [-105.025108484, 39.667715969], [-105.025110891, 39.666944008], [-105.025107146, 39.666274475], [-105.025104592, 39.665817713], [-105.025120294, 39.66533357], [-105.025123842, 39.665038796], [-105.025135254, 39.664069667], [-105.025136924, 39.663725303], [-105.0251482, 39.662120012], [-105.025158191, 39.660502212], [-105.025180161, 39.657429869], [-105.025195079, 39.656814817], [-105.025221498, 39.655301392], [-105.025229001, 39.654385999], [-105.025227999, 39.653248999]]], &quot;type&quot;: &quot;MultiLineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_342fb701cdaf1358c3722a174e791d60_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;};
#             }
#         }
#
#         function geo_json_342fb701cdaf1358c3722a174e791d60_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_342fb701cdaf1358c3722a174e791d60 = L.geoJson(null, {
#                 onEachFeature: geo_json_342fb701cdaf1358c3722a174e791d60_onEachFeature,
#
#                 style: geo_json_342fb701cdaf1358c3722a174e791d60_styler,
#         });
#
#         function geo_json_342fb701cdaf1358c3722a174e791d60_add (data) {
#             geo_json_342fb701cdaf1358c3722a174e791d60
#                 .addData(data)
#                 .addTo(map_ea630517a1831479c1683cf30312a774);
#         }
#             g

# %%
comparison.sort_values(by='diff_expected_crashes')[[
    'gid'
    , 'fullname'
    , 'length_miles'
    , 'crashes_per_mile_per_week_all_time'
    , 'crashes_per_mile_per_week_last_month'
    , 'diff_pmpw'
    , 'expected_crashes'
    , 'num_crashes_last_month'
    , 'diff_expected_crashes'
]]
# Out:
#       gid         fullname  length_miles  crashes_per_mile_per_week_all_time
# 22   7584   S FEDERAL BLVD      4.373528                            0.928451  \
# 34   4552     LEETSDALE DR      2.002250                            0.802128
# 28   6476    S SANTA FE DR      3.537547                            0.826630
# 5    1012     E COLFAX AVE      5.475202                            1.202391
# 71   3890  N SHERIDAN BLVD      5.135898                            0.525121
# ..    ...              ...           ...                                 ...
# 43   1799   N JOSEPHINE ST      1.876373                            0.686366
# 23   2941       N TOWER RD      1.027545                            0.910526
# 6    1714     N LINCOLN ST      2.165535                            1.184185
# 53    156        E 1ST AVE      1.225738                            0.621147
# 124  2938       N TOWER RD      7.211247                            0.364015
#
#      crashes_per_mile_per_week_last_month  diff_pmpw  expected_crashes
# 22                               0.586864  -0.341587         17.402597  \
# 34                               0.116536  -0.685592          6.883117
# 28                               0.461714  -0.364916         12.532468
# 5                                0.980177  -0.222214         28.214286
# 71                               0.318023  -0.207098         11.558442
# ..                                    ...        ...               ...
# 43                               1.243534   0.557168          5.519481
# 23                               2.043707   1.133181          4.009740
# 6                                1.831726   0.647541         10.990260
# 53                               1.903615   1.282468          3.262987
# 124                              0.582424   0.218409         11.250000
#
#      num_crashes_last_month  diff_expected_crashes
# 22                       11              -6.402597
# 34                        1              -5.883117
# 28                        7              -5.532468
# 5                        23              -5.214286
# 71                        7              -4.558442
# ..                      ...                    ...
# 43                       10               4.480519
# 23                        9               4.990260
# 6                        17               6.009740
# 53                       10               6.737013
# 124                      18               6.750000
#
# [186 rows x 9 columns]

# %%
comparison = comparison.sort_values(by='diff_expected_crashes')

comparison.loc[comparison['diff_expected_crashes'].rank() <= 5, 'Leaderboard'] = (
    comparison.loc[comparison['diff_expected_crashes'].rank() <= 5].apply(
        lambda row: f'{row.diff_expected_crashes:.0f} crashes'
        , axis=1
    )
)

comparison.loc[comparison['diff_expected_crashes'].rank(ascending=False) <= 5, 'Leaderboard'] = (
    comparison.loc[comparison['diff_expected_crashes'].rank(ascending=False) <= 5].apply(
        lambda row: f'+{row.diff_expected_crashes:.0f} crashes'
        , axis=1
    )
)

# comparison['Expected Crashes'] = comparison.expected_c

# %%
comparison['street_name'] = comparison['fullname'].str.title()
comparison.loc[
    comparison.Leaderboard.notnull()
    , ['street_name', 'expected_crashes', 'num_crashes_last_month', 'Leaderboard']
].style.format('{:.1f}', subset='expected_crashes')
# Out:
# <style type="text/css">
# </style>
# <table id="T_f01d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f01d4_level0_col0" class="col_heading level0 col0" >street_name</th>
#       <th id="T_f01d4_level0_col1" class="col_heading level0 col1" >expected_crashes</th>
#       <th id="T_f01d4_level0_col2" class="col_heading level0 col2" >num_crashes_last_month</th>
#       <th id="T_f01d4_level0_col3" class="col_heading level0 col3" >Leaderboard</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f01d4_level0_row0" class="row_heading level0 row0" >22</th>
#       <td id="T_f01d4_row0_col0" class="data row0 col0" >S Federal Blvd</td>
#       <td id="T_f01d4_row0_col1" class="data row0 col1" >17.4</td>
#       <td id="T_f01d4_row0_col2" class="data row0 col2" >11</td>
#       <td id="T_f01d4_row0_col3" class="data row0 col3" >-6 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_f01d4_level0_row1" class="row_heading level0 row1" >34</th>
#       <td id="T_f01d4_row1_col0" class="data row1 col0" >Leetsdale Dr</td>
#       <td id="T_f01d4_row1_col1" class="data row1 col1" >6.9</td>
#       <td id="T_f01d4_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_f01d4_row1_col3" class="data row1 col3" >-6 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_f01d4_level0_row2" class="row_heading level0 row2" >28</th>
#       <td id="T_f01d4_row2_col0" class="data row2 col0" >S Santa Fe Dr</td>
#       <td id="T_f01d4_row2_col1" class="data row2 col1" >12.5</td>
#       <td id="T_f01d4_row2_col2" class="data row2 col2" >7</td>
#       <td id="T_f01d4_row2_col3" class="data row2 col3" >-6 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_f01d4_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_f01d4_row3_col0" class="data row3 col0" >E Colfax Ave</td>
#       <td id="T_f01d4_row3_col1" class="data row3 col1" >28.2</td>
#       <td id="T_f01d4_row3_col2" class="data row3 col2" >23</td>
#       <td id="T_f01d4_row3_col3" class="data row3 col3" >-5 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_f01d4_level0_row4" class="row_heading level0 row4" >71</th>
#       <td id="T_f01d4_row4_col0" class="data row4 col0" >N Sheridan Blvd</td>
#       <td id="T_f01d4_row4_col1" class="data row4 col1" >11.6</td>
#       <td id="T_f01d4_row4_col2" class="data row4 col2" >7</td>
#       <td id="T_f01d4_row4_col3" class="data row4 col3" >-5 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_f01d4_level0_row5" class="row_heading level0 row5" >43</th>
#       <td id="T_f01d4_row5_col0" class="data row5 col0" >N Josephine St</td>
#       <td id="T_f01d4_row5_col1" class="data row5 col1" >5.5</td>
#       <td id="T_f01d4_row5_col2" class="data row5 col2" >10</td>
#       <td id="T_f01d4_row5_col3" class="data row5 col3" >+4 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_f01d4_level0_row6" class="row_heading level0 row6" >23</th>
#       <td id="T_f01d4_row6_col0" class="data row6 col0" >N Tower Rd</td>
#       <td id="T_f01d4_row6_col1" class="data row6 col1" >4.0</td>
#       <td id="T_f01d4_row6_col2" class="data row6 col2" >9</td>
#       <td id="T_f01d4_row6_col3" class="data row6 col3" >+5 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_f01d4_level0_row7" class="row_heading level0 row7" >6</th>
#       <td id="T_f01d4_row7_col0" class="data row7 col0" >N Lincoln St</td>
#       <td id="T_f01d4_row7_col1" class="data row7 col1" >11.0</td>
#       <td id="T_f01d4_row7_col2" class="data row7 col2" >17</td>
#       <td id="T_f01d4_row7_col3" class="data row7 col3" >+6 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_f01d4_level0_row8" class="row_heading level0 row8" >53</th>
#       <td id="T_f01d4_row8_col0" class="data row8 col0" >E 1St Ave</td>
#       <td id="T_f01d4_row8_col1" class="data row8 col1" >3.3</td>
#       <td id="T_f01d4_row8_col2" class="data row8 col2" >10</td>
#       <td id="T_f01d4_row8_col3" class="data row8 col3" >+7 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_f01d4_level0_row9" class="row_heading level0 row9" >124</th>
#       <td id="T_f01d4_row9_col0" class="data row9 col0" >N Tower Rd</td>
#       <td id="T_f01d4_row9_col1" class="data row9 col1" >11.2</td>
#       <td id="T_f01d4_row9_col2" class="data row9 col2" >18</td>
#       <td id="T_f01d4_row9_col3" class="data row9 col3" >+7 crashes</td>
#     </tr>
#   </tbody>
# </table>
