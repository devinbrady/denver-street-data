# %% [markdown]
# # Most Dangerous Streets - Crash Leaderboard
#
# Compare the most recent month to the all-time numbers to see which streets got safer.

# %%
import pytz
import folium
import pandas as pd
from datetime import datetime, timedelta

import os
os.chdir('..')
from scripts.crash_data_analysis import CrashDataAnalysis

# %%
cda = CrashDataAnalysis()

# %%
start_date = pytz.timezone('America/Denver').localize(datetime(2020,7,1))
end_date = cda.most_recent_crash_timestamp()

all_time = cda.street_metrics(start_date, end_date)

# %%
start_date = pytz.timezone('America/Denver').localize(datetime(2023,6,1))
end_date = pytz.timezone('America/Denver').localize(datetime(2023,7,1))

last_month = cda.street_metrics(start_date, end_date)

# %%
# A street must have at least 100 crashes all-time to be in the comparison
all_time = all_time[all_time.num_crashes >= 100].copy()

# %%
all_time
# Out:
#        gid      lrsroute                      fullname  length_miles
# 1585  3900   SPEERN   BD                  N SPEER BLVD      2.634723  \
# 1764  4229   22ND     ST                       22ND ST      1.079568
# 2411  5587   PARK     AV                    PARK AVE W      1.809664
# 1015  1957   MARKET   ST                     MARKET ST      0.920197
# 756   1452   ESPEERN  BD                  E SPEER BLVD      1.060124
# ...    ...           ...                           ...           ...
# 3182  7738   SLOGAN   ST                    S LOGAN ST      3.377398
# 332    572   56TH     AV                    E 56TH AVE      9.027374
# 113    174  23RD     AV1                    E 23RD AVE      4.660338
# 175    291  35TH     AV1                    E 35TH AVE      4.421519
# 1016  1958   MARTINLUTBD  E MARTIN LUTHER KING JR BLVD      3.328518
#
#                                             street_line  num_crashes  num_sbi
# 1585  {"type":"MultiLineString","coordinates":[[[-10...          705       22  \
# 1764  {"type":"MultiLineString","coordinates":[[[-10...          234        4
# 2411  {"type":"MultiLineString","coordinates":[[[-10...          377       12
# 1015  {"type":"MultiLineString","coordinates":[[[-10...          185        7
# 756   {"type":"MultiLineString","coordinates":[[[-10...          209        6
# ...                                                 ...          ...      ...
# 3182  {"type":"MultiLineString","coordinates":[[[-10...          128        2
# 332   {"type":"MultiLineString","coordinates":[[[-10...          318       12
# 113   {"type":"MultiLineString","coordinates":[[[-10...          155        4
# 175   {"type":"MultiLineString","coordinates":[[[-10...          139        3
# 1016  {"type":"MultiLineString","coordinates":[[[-10...          100        4
#
#       num_fatality  num_sbi_or_fatality  days_in_data  days_between_crashes
# 1585             5                   27          1098              1.557447  \
# 1764             2                    6          1098              4.692308
# 2411             2                   14          1098              2.912467
# 1015             0                    7          1098              5.935135
# 756              2                    8          1098              5.253589
# ...            ...                  ...           ...                   ...
# 3182             0                    2          1098              8.578125
# 332              3                   15          1098              3.452830
# 113              1                    5          1098              7.083871
# 175              1                    4          1098              7.899281
# 1016             1                    5          1098             10.980000
#
#       crashes_per_mile_per_week
# 1585                   1.705885
# 1764                   1.381852
# 2411                   1.328125
# 1015                   1.281700
# 756                    1.256856
# ...                         ...
# 3182                   0.241615
# 332                    0.224575
# 113                    0.212036
# 175                    0.200419
# 1016                   0.191534
#
# [124 rows x 12 columns]

# %%
comparison = pd.merge(
    all_time
    , last_month
    , how='inner'
    , on=['gid', 'lrsroute', 'fullname', 'length_miles','street_line']
    , suffixes=['_all_time', '_last_month']
)

# %%
comparison['diff_pmpw'] = (
    comparison['crashes_per_mile_per_week_last_month']
    - comparison['crashes_per_mile_per_week_all_time']
)

# %%
comparison['expected_crashes'] = (
    comparison['length_miles']
    * comparison['crashes_per_mile_per_week_all_time']
    * (comparison['days_in_data_last_month'] / 7)
)

comparison['diff_expected_crashes'] = comparison['num_crashes_last_month'] - comparison['expected_crashes']

# %% [markdown]
# ## Difference in Crash Rate per Mile

# %%
this_map = folium.Map(prefer_canvas=True, tiles='Stamen Toner')

good_streets = comparison.sort_values(by='diff_pmpw').head(5)['street_line']
bad_streets = comparison.sort_values(by='diff_pmpw').tail(5)['street_line']

for good_street in good_streets:
    folium.GeoJson(good_street, style_function=lambda x: {'color': 'green'}).add_to(this_map)

for bad_street in bad_streets:
    folium.GeoJson(bad_street, style_function=lambda x: {'color': 'red'}).add_to(this_map)
    
this_map.fit_bounds(this_map.get_bounds())
this_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bbfa73d2c12753e2a9e92639280a69dc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bbfa73d2c12753e2a9e92639280a69dc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bbfa73d2c12753e2a9e92639280a69dc = L.map(
#                 &quot;map_bbfa73d2c12753e2a9e92639280a69dc&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_37e913a42fc2e3b36d2b2b85c0fd18b5 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bbfa73d2c12753e2a9e92639280a69dc);
#
#
#         function geo_json_7f7eef36661808afe2f87e55a14cdbdf_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;};
#             }
#         }
#
#         function geo_json_7f7eef36661808afe2f87e55a14cdbdf_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_7f7eef36661808afe2f87e55a14cdbdf = L.geoJson(null, {
#                 onEachFeature: geo_json_7f7eef36661808afe2f87e55a14cdbdf_onEachFeature,
#
#                 style: geo_json_7f7eef36661808afe2f87e55a14cdbdf_styler,
#         });
#
#         function geo_json_7f7eef36661808afe2f87e55a14cdbdf_add (data) {
#             geo_json_7f7eef36661808afe2f87e55a14cdbdf
#                 .addData(data)
#                 .addTo(map_bbfa73d2c12753e2a9e92639280a69dc);
#         }
#             geo_json_7f7eef36661808afe2f87e55a14cdbdf_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-104.809788843, 39.772833103], [-104.809879307, 39.77318835], [-104.80989792, 39.775048907], [-104.809906437, 39.77668142], [-104.80987678, 39.778472187], [-104.809849005, 39.780345606], [-104.809797351, 39.783755499], [-104.809769772, 39.787868446], [-104.80975347, 39.790354576], [-104.809721906, 39.794791358], [-104.809709884, 39.796736292], [-104.809690925, 39.796984538], [-104.809688944, 39.797029354], [-104.809602486, 39.798305006]]], &quot;type&quot;: &quot;MultiLineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_90467cba53bb49c8d65d16a5a2117dbc_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;};
#             }
#         }
#
#         function geo_json_90467cba53bb49c8d65d16a5a2117dbc_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_90467cba53bb49c8d65d16a5a2117dbc = L.geoJson(null, {
#                 onEachFeature: geo_json_90467cba53bb49c8d65d16a5a2117dbc_onEachFeature,
#
#                 style: geo_json_90467cba53bb49c8d65d16a5a2117dbc_styler,
#         });
#
#         function geo_json_90467cba53bb49c8d65d16a5a2117dbc_add (data) {
#             geo_json_90467cba53bb49c8d65d16a5a2117dbc
#                 .addData(data)
#                 .addTo(map_bbfa73d2c12753e2a9e92639280a69dc);
#         }
#             geo_json_90467cba53bb49c8d65d16a5a2117dbc_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-104.983789851, 39.716539645], [-104.983761027, 39.718283114], [-104.983790822, 39.718339526], [-104.983791358, 39.719354599], [-104.983788395, 39.720965096], [-104.983802538, 39.722545356], [-104.983798124, 39.723015813], [-104.983794299, 39.723423469], [-104.983739446, 39.723626661], [-104.983648108, 39.723965023], [-104.983629145, 39.724126225], [-104.983621619, 39.725238373], [-104.983618964, 39.725630599], [-104.983620577, 39.726377317], [-104.983622786, 39.727284642], [-104.983598958, 39.72907206], [-104.983603106, 39.730440942], [-104.983581546, 39.732041001], [-104.983594145, 39.733831318], [-104.983593775, 39.734967862], [-104.983593309, 39.735272585], [-104.98361908, 39.736843679], [-104.983594908, 39.738436517], [-104.98358394, 39.740046568], [-104.983589722, 39.741675908], [-104.983589816, 39.742503611], [-104.983589817, 39.742508411], [-104.983588637, 39.743271933], [-104.983584888, 39.744867945], [-104.983589417, 39.746184659], [-104.983590018, 39.747551803], [-104.983593113, 39.747604934], [-104.983589704, 39.747687166], [-104.983589593, 39.747702314], [-104.98358655, 39.747734765], [-104.983528773, 39.747853958]]], &quot;type&quot;: &quot;MultiLineString&quot;}, &quot;id&quot;: &quot;0&

# %%
comparison.sort_values(by='diff_pmpw')[[
    'gid'
    , 'fullname'
    , 'length_miles'
    , 'crashes_per_mile_per_week_all_time'
    , 'crashes_per_mile_per_week_last_month'
    , 'diff_pmpw'
    , 'num_crashes_all_time'
    , 'num_crashes_last_month'
    , 'expected_crashes'
    , 'diff_expected_crashes'
]]
# Out:
#      gid        fullname  length_miles  crashes_per_mile_per_week_all_time
# 20  1122   N CHAMBERS RD      1.758017                            0.899341  \
# 41  1415      N GRANT ST      2.162158                            0.633938
# 42   156       E 1ST AVE      1.225738                            0.629337
# 10  5588      PARK AVE W      0.651755                            1.144450
# 9   1714    N LINCOLN ST      2.165535                            1.189356
# ..   ...             ...           ...                                 ...
# 17  2127     N PEORIA ST      2.089566                            0.985467
# 21  2941      N TOWER RD      1.027545                            0.887220
# 3   1957       MARKET ST      0.920197                            1.281700
# 33  1799  N JOSEPHINE ST      1.876373                            0.716901
# 12  4216         17TH ST      0.928871                            1.043240
#
#     crashes_per_mile_per_week_last_month  diff_pmpw  num_crashes_all_time
# 20                              0.132725  -0.766615                   248  \
# 41                              0.107917  -0.526021                   215
# 42                              0.190361  -0.438976                   121
# 10                              0.716015  -0.428435                   117
# 9                               0.861989  -0.327367                   404
# ..                                   ...        ...                   ...
# 17                              1.674989   0.689522                   323
# 21                              1.589550   0.702330                   143
# 3                               2.028551   0.746850                   185
# 33                              1.492241   0.775340                   211
# 12                              2.763213   1.719973                   152
#
#     num_crashes_last_month  expected_crashes  diff_expected_crashes
# 20                       1          6.775956              -5.775956
# 41                       1          5.874317              -4.874317
# 42                       1          3.306011              -2.306011
# 10                       2          3.196721              -1.196721
# 9                        8         11.038251              -3.038251
# ..                     ...               ...                    ...
# 17                      15          8.825137               6.174863
# 21                       7          3.907104               3.092896
# 3                        8          5.054645               2.945355
# 33                      12          5.765027               6.234973
# 12                      11          4.153005               6.846995
#
# [123 rows x 10 columns]

# %% [markdown]
# ## Difference in Number of Expected Crashes

# %%
this_map = folium.Map(prefer_canvas=True, tiles='Stamen Toner')

good_streets = comparison.sort_values(by='diff_expected_crashes').head(5)['street_line']
bad_streets = comparison.sort_values(by='diff_expected_crashes').tail(5)['street_line']

for good_street in good_streets:
    folium.GeoJson(good_street, style_function=lambda x: {'color': 'green'}).add_to(this_map)

for bad_street in bad_streets:
    folium.GeoJson(bad_street, style_function=lambda x: {'color': 'red'}).add_to(this_map)
    
this_map.fit_bounds(this_map.get_bounds())
this_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f48a95dcde61f161cf2aa739e42e9e86 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f48a95dcde61f161cf2aa739e42e9e86&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f48a95dcde61f161cf2aa739e42e9e86 = L.map(
#                 &quot;map_f48a95dcde61f161cf2aa739e42e9e86&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_804c21b033200cd2d06decda63b576dd = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f48a95dcde61f161cf2aa739e42e9e86);
#
#
#         function geo_json_752f4fefd11bfcb735d5dd10bf1b8c8e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;};
#             }
#         }
#
#         function geo_json_752f4fefd11bfcb735d5dd10bf1b8c8e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_752f4fefd11bfcb735d5dd10bf1b8c8e = L.geoJson(null, {
#                 onEachFeature: geo_json_752f4fefd11bfcb735d5dd10bf1b8c8e_onEachFeature,
#
#                 style: geo_json_752f4fefd11bfcb735d5dd10bf1b8c8e_styler,
#         });
#
#         function geo_json_752f4fefd11bfcb735d5dd10bf1b8c8e_add (data) {
#             geo_json_752f4fefd11bfcb735d5dd10bf1b8c8e
#                 .addData(data)
#                 .addTo(map_f48a95dcde61f161cf2aa739e42e9e86);
#         }
#             geo_json_752f4fefd11bfcb735d5dd10bf1b8c8e_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-104.809788843, 39.772833103], [-104.809879307, 39.77318835], [-104.80989792, 39.775048907], [-104.809906437, 39.77668142], [-104.80987678, 39.778472187], [-104.809849005, 39.780345606], [-104.809797351, 39.783755499], [-104.809769772, 39.787868446], [-104.80975347, 39.790354576], [-104.809721906, 39.794791358], [-104.809709884, 39.796736292], [-104.809690925, 39.796984538], [-104.809688944, 39.797029354], [-104.809602486, 39.798305006]]], &quot;type&quot;: &quot;MultiLineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_992dcba86b995deaf5bdcfc55ab5ed6c_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;};
#             }
#         }
#
#         function geo_json_992dcba86b995deaf5bdcfc55ab5ed6c_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_992dcba86b995deaf5bdcfc55ab5ed6c = L.geoJson(null, {
#                 onEachFeature: geo_json_992dcba86b995deaf5bdcfc55ab5ed6c_onEachFeature,
#
#                 style: geo_json_992dcba86b995deaf5bdcfc55ab5ed6c_styler,
#         });
#
#         function geo_json_992dcba86b995deaf5bdcfc55ab5ed6c_add (data) {
#             geo_json_992dcba86b995deaf5bdcfc55ab5ed6c
#                 .addData(data)
#                 .addTo(map_f48a95dcde61f161cf2aa739e42e9e86);
#         }
#             geo_json_992dcba86b995deaf5bdcfc55ab5ed6c_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-104.983789851, 39.716539645], [-104.983761027, 39.718283114], [-104.983790822, 39.718339526], [-104.983791358, 39.719354599], [-104.983788395, 39.720965096], [-104.983802538, 39.722545356], [-104.983798124, 39.723015813], [-104.983794299, 39.723423469], [-104.983739446, 39.723626661], [-104.983648108, 39.723965023], [-104.983629145, 39.724126225], [-104.983621619, 39.725238373], [-104.983618964, 39.725630599], [-104.983620577, 39.726377317], [-104.983622786, 39.727284642], [-104.983598958, 39.72907206], [-104.983603106, 39.730440942], [-104.983581546, 39.732041001], [-104.983594145, 39.733831318], [-104.983593775, 39.734967862], [-104.983593309, 39.735272585], [-104.98361908, 39.736843679], [-104.983594908, 39.738436517], [-104.98358394, 39.740046568], [-104.983589722, 39.741675908], [-104.983589816, 39.742503611], [-104.983589817, 39.742508411], [-104.983588637, 39.743271933], [-104.983584888, 39.744867945], [-104.983589417, 39.746184659], [-104.983590018, 39.747551803], [-104.983593113, 39.747604934], [-104.983589704, 39.747687166], [-104.983589593, 39.747702314], [-104.98358655, 39.747734765], [-104.983528773, 39.747853958]]], &quot;type&quot;: &quot;MultiLineString&quot;}, &quot;id&quot;: &quot;0&

# %%
comparison.sort_values(by='diff_expected_crashes')[[
    'gid'
    , 'fullname'
    , 'length_miles'
    , 'crashes_per_mile_per_week_all_time'
    , 'crashes_per_mile_per_week_last_month'
    , 'diff_pmpw'
    , 'expected_crashes'
    , 'num_crashes_last_month'
    , 'diff_expected_crashes'
]]
# Out:
#      gid             fullname  length_miles
# 20  1122        N CHAMBERS RD      1.758017  \
# 41  1415           N GRANT ST      2.162158
# 26  4689       N FEDERAL BLVD      5.367276
# 27  4592      S COLORADO BLVD      4.362694
# 18  5379         W COLFAX AVE      3.567320
# ..   ...                  ...           ...
# 33  1799       N JOSEPHINE ST      1.876373
# 92   920  N CENTRAL PARK BLVD      4.490628
# 12  4216              17TH ST      0.928871
# 49   125           E 14TH AVE      5.479802
# 0   3900         N SPEER BLVD      2.634723
#
#     crashes_per_mile_per_week_all_time  crashes_per_mile_per_week_last_month
# 20                            0.899341                              0.132725  \
# 41                            0.633938                              0.107917
# 26                            0.852837                              0.652100
# 27                            0.827099                              0.588321
# 18                            0.945386                              0.719494
# ..                                 ...                                   ...
# 33                            0.716901                              1.492241
# 92                            0.401768                              0.727441
# 12                            1.043240                              2.763213
# 49                            0.588683                              0.894193
# 0                             1.705885                              2.391143
#
#     diff_pmpw  expected_crashes  num_crashes_last_month  diff_expected_crashes
# 20  -0.766615          6.775956                       1              -5.775956
# 41  -0.526021          5.874317                       1              -4.874317
# 26  -0.200737         19.617486                      15              -4.617486
# 27  -0.238777         15.464481                      11              -4.464481
# 18  -0.225892         14.453552                      11              -3.453552
# ..        ...               ...                     ...                    ...
# 33   0.775340          5.765027                      12               6.234973
# 92   0.325673          7.732240                      14               6.267760
# 12   1.719973          4.153005                      11               6.846995
# 49   0.305510         13.825137                      21               7.174863
# 0    0.685258         19.262295                      27               7.737705
#
# [123 rows x 9 columns]

# %%
comparison = comparison.sort_values(by='diff_expected_crashes')

comparison.loc[comparison['diff_expected_crashes'].rank() <= 5, 'Leaderboard'] = (
    comparison.loc[comparison['diff_expected_crashes'].rank() <= 5].apply(
        lambda row: f'{row.diff_expected_crashes:.0f} crashes'
        , axis=1
    )
)

comparison.loc[comparison['diff_expected_crashes'].rank(ascending=False) <= 5, 'Leaderboard'] = (
    comparison.loc[comparison['diff_expected_crashes'].rank(ascending=False) <= 5].apply(
        lambda row: f'+{row.diff_expected_crashes:.0f} crashes'
        , axis=1
    )
)

# comparison['Expected Crashes'] = comparison.expected_c

# %%
comparison['street_name'] = comparison['fullname'].str.title()
comparison.loc[
    comparison.leaderboard.notnull()
    , ['street_name', 'expected_crashes', 'num_crashes_last_month', 'leaderboard']
].style.format('{:.1f}', subset='expected_crashes')
# Out:
# <style type="text/css">
# </style>
# <table id="T_de7d6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de7d6_level0_col0" class="col_heading level0 col0" >street_name</th>
#       <th id="T_de7d6_level0_col1" class="col_heading level0 col1" >expected_crashes</th>
#       <th id="T_de7d6_level0_col2" class="col_heading level0 col2" >num_crashes_last_month</th>
#       <th id="T_de7d6_level0_col3" class="col_heading level0 col3" >leaderboard</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de7d6_level0_row0" class="row_heading level0 row0" >20</th>
#       <td id="T_de7d6_row0_col0" class="data row0 col0" >N Chambers Rd</td>
#       <td id="T_de7d6_row0_col1" class="data row0 col1" >6.8</td>
#       <td id="T_de7d6_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_de7d6_row0_col3" class="data row0 col3" >-6 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_de7d6_level0_row1" class="row_heading level0 row1" >41</th>
#       <td id="T_de7d6_row1_col0" class="data row1 col0" >N Grant St</td>
#       <td id="T_de7d6_row1_col1" class="data row1 col1" >5.9</td>
#       <td id="T_de7d6_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_de7d6_row1_col3" class="data row1 col3" >-5 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_de7d6_level0_row2" class="row_heading level0 row2" >26</th>
#       <td id="T_de7d6_row2_col0" class="data row2 col0" >N Federal Blvd</td>
#       <td id="T_de7d6_row2_col1" class="data row2 col1" >19.6</td>
#       <td id="T_de7d6_row2_col2" class="data row2 col2" >15</td>
#       <td id="T_de7d6_row2_col3" class="data row2 col3" >-5 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_de7d6_level0_row3" class="row_heading level0 row3" >27</th>
#       <td id="T_de7d6_row3_col0" class="data row3 col0" >S Colorado Blvd</td>
#       <td id="T_de7d6_row3_col1" class="data row3 col1" >15.5</td>
#       <td id="T_de7d6_row3_col2" class="data row3 col2" >11</td>
#       <td id="T_de7d6_row3_col3" class="data row3 col3" >-4 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_de7d6_level0_row4" class="row_heading level0 row4" >18</th>
#       <td id="T_de7d6_row4_col0" class="data row4 col0" >W Colfax Ave</td>
#       <td id="T_de7d6_row4_col1" class="data row4 col1" >14.5</td>
#       <td id="T_de7d6_row4_col2" class="data row4 col2" >11</td>
#       <td id="T_de7d6_row4_col3" class="data row4 col3" >-3 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_de7d6_level0_row5" class="row_heading level0 row5" >33</th>
#       <td id="T_de7d6_row5_col0" class="data row5 col0" >N Josephine St</td>
#       <td id="T_de7d6_row5_col1" class="data row5 col1" >5.8</td>
#       <td id="T_de7d6_row5_col2" class="data row5 col2" >12</td>
#       <td id="T_de7d6_row5_col3" class="data row5 col3" >+6 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_de7d6_level0_row6" class="row_heading level0 row6" >92</th>
#       <td id="T_de7d6_row6_col0" class="data row6 col0" >N Central Park Blvd</td>
#       <td id="T_de7d6_row6_col1" class="data row6 col1" >7.7</td>
#       <td id="T_de7d6_row6_col2" class="data row6 col2" >14</td>
#       <td id="T_de7d6_row6_col3" class="data row6 col3" >+6 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_de7d6_level0_row7" class="row_heading level0 row7" >12</th>
#       <td id="T_de7d6_row7_col0" class="data row7 col0" >17Th St</td>
#       <td id="T_de7d6_row7_col1" class="data row7 col1" >4.2</td>
#       <td id="T_de7d6_row7_col2" class="data row7 col2" >11</td>
#       <td id="T_de7d6_row7_col3" class="data row7 col3" >+7 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_de7d6_level0_row8" class="row_heading level0 row8" >49</th>
#       <td id="T_de7d6_row8_col0" class="data row8 col0" >E 14Th Ave</td>
#       <td id="T_de7d6_row8_col1" class="data row8 col1" >13.8</td>
#       <td id="T_de7d6_row8_col2" class="data row8 col2" >21</td>
#       <td id="T_de7d6_row8_col3" class="data row8 col3" >+7 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_de7d6_level0_row9" class="row_heading level0 row9" >0</th>
#       <td id="T_de7d6_row9_col0" class="data row9 col0" >N Speer Blvd</td>
#       <td id="T_de7d6_row9_col1" class="data row9 col1" >19.3</td>
#       <td id="T_de7d6_row9_col2" class="data row9 col2" >27</td>
#       <td id="T_de7d6_row9_col3" class="data row9 col3" >+8 crashes</td>
#     </tr>
#   </tbody>
# </table>
