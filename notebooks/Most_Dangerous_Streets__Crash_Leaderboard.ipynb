# %% [markdown]
# # Most Dangerous Streets - Crash Leaderboard
#
# Compare the most recent month to the all-time numbers to see which streets got safer.

# %%
import pytz
import folium
import pandas as pd
from datetime import datetime, timedelta
from crash_data_analysis import CrashDataAnalysis

# %%
cda = CrashDataAnalysis()

# %%
start_date = pytz.timezone('America/Denver').localize(datetime(2020,7,1))
end_date = cda.most_recent_crash_timestamp()

all_time = cda.street_metrics(start_date, end_date)

# %%
start_date = pytz.timezone('America/Denver').localize(datetime(2023,3,1))
end_date = pytz.timezone('America/Denver').localize(datetime(2023,4,1))

last_month = cda.street_metrics(start_date, end_date)

# %%
# A street must have at least 100 crashes all-time to be in the comparison
all_time = all_time[all_time.num_crashes >= 100].copy()

# %%
all_time
# Out:
#        gid      lrsroute         fullname  length_miles
# 1535  3900   SPEERN   BD     N SPEER BLVD      2.634723  \
# 1710  4229   22ND     ST          22ND ST      1.079568
# 2344  5587   PARK     AV       PARK AVE W      1.809664
# 524   1012   COLFAX   AV     E COLFAX AVE      5.475202
# 452    880     BROADWAY3       N BROADWAY      3.331934
# ...    ...           ...              ...           ...
# 448    875   BRIGHTON BD  N BRIGHTON BLVD      2.807560
# 3098  7738   SLOGAN   ST       S LOGAN ST      3.377398
# 324    572   56TH     AV       E 56TH AVE      9.027374
# 109    174  23RD     AV1       E 23RD AVE      4.660338
# 170    291  35TH     AV1       E 35TH AVE      4.421519
#
#                                             street_line  num_crashes  num_sbi
# 1535  {"type":"MultiLineString","coordinates":[[[-10...          642       20  \
# 1710  {"type":"MultiLineString","coordinates":[[[-10...          206        4
# 2344  {"type":"MultiLineString","coordinates":[[[-10...          345       12
# 524   {"type":"MultiLineString","coordinates":[[[-10...          990       47
# 452   {"type":"MultiLineString","coordinates":[[[-10...          592       20
# ...                                                 ...          ...      ...
# 448   {"type":"MultiLineString","coordinates":[[[-10...          104        4
# 3098  {"type":"MultiLineString","coordinates":[[[-10...          123        2
# 324   {"type":"MultiLineString","coordinates":[[[-10...          296       12
# 109   {"type":"MultiLineString","coordinates":[[[-10...          145        4
# 170   {"type":"MultiLineString","coordinates":[[[-10...          129        3
#
#       num_fatality  num_sbi_or_fatality  days_in_data  days_between_crashes
# 1535             5                   25          1007              1.568536  \
# 1710             2                    6          1007              4.888350
# 2344             3                   15          1007              2.918841
# 524              5                   52          1007              1.017172
# 452              9                   29          1007              1.701014
# ...            ...                  ...           ...                   ...
# 448              2                    6          1007              9.682692
# 3098             0                    2          1007              8.186992
# 324              3                   15          1007              3.402027
# 109              1                    5          1007              6.944828
# 170              1                    4          1007              7.806202
#
#       crashes_per_mile_per_week
# 1535                   1.693825
# 1710                   1.326435
# 2344                   1.325225
# 524                    1.256908
# 452                    1.235076
# ...                         ...
# 448                    0.257497
# 3098                   0.253158
# 324                    0.227929
# 109                    0.216281
# 170                    0.202809
#
# [116 rows x 12 columns]

# %%
comparison = pd.merge(
    all_time
    , last_month
    , how='inner'
    , on=['gid', 'lrsroute', 'fullname', 'length_miles','street_line']
    , suffixes=['_all_time', '_last_month']
)

# %%
comparison['diff_pmpw'] = (
    comparison['crashes_per_mile_per_week_last_month']
    - comparison['crashes_per_mile_per_week_all_time']
)

# %%
comparison['expected_crashes'] = (
    comparison['length_miles']
    * comparison['crashes_per_mile_per_week_all_time']
    * (comparison['days_in_data_last_month'] / 7)
)

comparison['diff_expected_crashes'] = comparison['num_crashes_last_month'] - comparison['expected_crashes']

# %% [markdown]
# ## Difference in Crash Rate per Mile

# %%
this_map = folium.Map(prefer_canvas=True, tiles='Stamen Toner')

good_streets = comparison.sort_values(by='diff_pmpw').head(5)['street_line']
bad_streets = comparison.sort_values(by='diff_pmpw').tail(5)['street_line']

for good_street in good_streets:
    folium.GeoJson(good_street, style_function=lambda x: {'color': 'green'}).add_to(this_map)

for bad_street in bad_streets:
    folium.GeoJson(bad_street, style_function=lambda x: {'color': 'red'}).add_to(this_map)
    
this_map.fit_bounds(this_map.get_bounds())
this_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd611446d7cbe30d41a6e4456fcd3892 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd611446d7cbe30d41a6e4456fcd3892&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd611446d7cbe30d41a6e4456fcd3892 = L.map(
#                 &quot;map_fd611446d7cbe30d41a6e4456fcd3892&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_40be86e977bd2fa71d516611e32b3a89 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fd611446d7cbe30d41a6e4456fcd3892);
#
#
#         function geo_json_333ff2e2cbb6b08cd6575149086c0bfd_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;};
#             }
#         }
#
#         function geo_json_333ff2e2cbb6b08cd6575149086c0bfd_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_333ff2e2cbb6b08cd6575149086c0bfd = L.geoJson(null, {
#                 onEachFeature: geo_json_333ff2e2cbb6b08cd6575149086c0bfd_onEachFeature,
#
#                 style: geo_json_333ff2e2cbb6b08cd6575149086c0bfd_styler,
#         });
#
#         function geo_json_333ff2e2cbb6b08cd6575149086c0bfd_add (data) {
#             geo_json_333ff2e2cbb6b08cd6575149086c0bfd
#                 .addData(data)
#                 .addTo(map_fd611446d7cbe30d41a6e4456fcd3892);
#         }
#             geo_json_333ff2e2cbb6b08cd6575149086c0bfd_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-104.998577297, 39.716597768], [-104.998575672, 39.717825635], [-104.998575524, 39.717938044], [-104.998574877, 39.718428521], [-104.998578862, 39.719362968], [-104.998578303, 39.720933269], [-104.998577535, 39.72253342], [-104.99857678, 39.724131174], [-104.998572631, 39.725706945], [-104.998602005, 39.727316491], [-104.998611091, 39.728905703], [-104.998631663, 39.730504229], [-104.998647811, 39.732099647], [-104.998656965, 39.733679587], [-104.998673163, 39.735268826], [-104.998690188, 39.736867329], [-104.998736723, 39.737832298], [-104.998738956, 39.737882362], [-104.998761798, 39.73795254], [-104.998784128, 39.738012679], [-104.998907146, 39.738118343], [-104.998999935, 39.738198833], [-104.999165127, 39.73830966], [-104.999198647, 39.738336524], [-104.999358291, 39.738464468], [-104.999626775, 39.738672033], [-104.999675751, 39.738714288], [-104.999745388, 39.738768646], [-104.999794274, 39.738822916], [-104.999850859, 39.73888923], [-104.999890722, 39.738936456], [-104.999920255, 39.738977623], [-104.999957384, 39.739044859], [-104.999968718, 39.73909196], [-104.999986371, 39.739162116], [-104.999996233, 39.739234238], [-104.99999811, 39.739334359], [-105.000002715, 39.739416473], [-105.000003766, 39.739454357], [-104.999982681, 39.739936706], [-105.000065948, 39.740109581], [-104.999961089, 39.740305628], [-104.999936319, 39.74056023], [-104.999927838, 39.740726341], [-104.999912768, 39.740793861], [-104.999868413, 39.740875336], [-104.999827791, 39.740945565], [-104.999765199, 39.741026965], [-104.999691784, 39.741091421], [-104.999487808, 39.741194521]]], &quot;type&quot;: &quot;MultiLineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_80dc327bb5e77ae05891768ea8117e06_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;};
#             }
#         }
#
#         function geo_json_80dc327bb5e77ae05891768ea8117e06_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_80dc327bb5e77ae05891768ea8117e06 = L.geoJson(null, {
#                 onEachFeature: geo_json_80dc327bb5e77ae05891768ea8117e06_onEachFeature,
#
#                 style: geo_json_80dc327bb5e77ae05891768ea8117e06_styler,
#         });
#
#         function geo_json_80dc327bb5e77ae05891768ea8117e06_add (data) {
#             geo_json_80dc327bb5e77ae05891768ea8117e06
#                 .addData(data)
#                 .addTo(map_fd611446d7cbe30d41a6e4456fcd3892);
#         }
#             geo_json_80dc327bb5e77ae05891768ea8117e06_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-104.985574132, 39.747596868], [-104.985699995, 39.747650264], [-104.986

# %%
comparison.sort_values(by='diff_pmpw')[[
    'gid'
    , 'fullname'
    , 'length_miles'
    , 'crashes_per_mile_per_week_all_time'
    , 'crashes_per_mile_per_week_last_month'
    , 'diff_pmpw'
    , 'num_crashes_all_time'
    , 'num_crashes_last_month'
    , 'expected_crashes'
    , 'diff_expected_crashes'
]]
# Out:
#      gid       fullname  length_miles  crashes_per_mile_per_week_all_time
# 20  3888  N SANTA FE DR      1.732911                            0.906569  \
# 7   4225        20TH ST      1.453330                            1.200544
# 30  7725   S LINCOLN ST      1.069023                            0.760795
# 48  3813      WELTON ST      1.769275                            0.573622
# 68  5589     N PECOS ST      2.001631                            0.468833
# ..   ...            ...           ...                                 ...
# 42   866       BLAKE ST      2.422119                            0.614167
# 27   136     E 18TH AVE      1.582608                            0.834543
# 9   5588     PARK AVE W      0.651755                            1.141216
# 1   4229        22ND ST      1.079568                            1.326435
# 2   5587     PARK AVE W      1.809664                            1.325225
#
#     crashes_per_mile_per_week_last_month  diff_pmpw  num_crashes_all_time
# 20                              0.269296  -0.637272                   226  \
# 7                               0.642203  -0.558341                   251
# 30                              0.218268  -0.542527                   117
# 48                              0.131881  -0.441742                   146
# 68                              0.116572  -0.352262                   135
# ..                                   ...        ...                   ...
# 42                              1.156012   0.541845                   214
# 27                              1.474359   0.639816                   190
# 9                               1.790038   0.648822                   107
# 1                               2.161359   0.834924                   206
# 2                               2.320873   0.995648                   345
#
#     num_crashes_last_month  expected_crashes  diff_expected_crashes
# 20                       2          6.732870              -4.732870
# 7                        4          7.477656              -3.477656
# 30                       1          3.485601              -2.485601
# 48                       1          4.349553              -3.349553
# 68                       1          4.021847              -3.021847
# ..                     ...               ...                    ...
# 42                      12          6.375372               5.624628
# 27                      10          5.660377               4.339623
# 9                        5          3.187686               1.812314
# 1                       10          6.137041               3.862959
# 2                       18         10.278054               7.721946
#
# [115 rows x 10 columns]

# %% [markdown]
# ## Difference in Number of Expected Crashes

# %%
this_map = folium.Map(prefer_canvas=True, tiles='Stamen Toner')

good_streets = comparison.sort_values(by='diff_expected_crashes').head(5)['street_line']
bad_streets = comparison.sort_values(by='diff_expected_crashes').tail(5)['street_line']

for good_street in good_streets:
    folium.GeoJson(good_street, style_function=lambda x: {'color': 'green'}).add_to(this_map)

for bad_street in bad_streets:
    folium.GeoJson(bad_street, style_function=lambda x: {'color': 'red'}).add_to(this_map)
    
this_map.fit_bounds(this_map.get_bounds())
this_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9fa4e25a5d6abcf24606e787048aa45a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_
# %%
comparison.sort_values(by='diff_expected_crashes')[[
    'gid'
    , 'fullname'
    , 'length_miles'
    , 'crashes_per_mile_per_week_all_time'
    , 'crashes_per_mile_per_week_last_month'
    , 'diff_pmpw'
    , 'expected_crashes'
    , 'num_crashes_last_month'
    , 'diff_expected_crashes'
]]
# Out:
#      gid         fullname  length_miles  crashes_per_mile_per_week_all_time
# 60  6481  S SHERIDAN BLVD      5.380667                            0.536143  \
# 12  1016  N COLORADO BLVD      5.184503                            1.032410
# 51  2474      N QUEBEC ST      5.785164                            0.565944
# 20  3888    N SANTA FE DR      1.732911                            0.906569
# 7   4225          20TH ST      1.453330                            1.200544
# ..   ...              ...           ...                                 ...
# 0   3900     N SPEER BLVD      2.634723                            1.693825
# 42   866         BLAKE ST      2.422119                            0.614167
# 64  2939       N TOWER RD      2.510320                            0.481824
# 2   5587       PARK AVE W      1.809664                            1.325225
# 19  7584   S FEDERAL BLVD      4.373528                            0.931396
#
#     crashes_per_mile_per_week_last_month  diff_pmpw  expected_crashes
# 60                              0.216826  -0.319317         12.363456  \
# 12                              0.765101  -0.267309         22.939424
# 51                              0.362997  -0.202947         14.031778
# 20                              0.269296  -0.637272          6.732870
# 7                               0.642203  -0.558341          7.477656
# ..                                   ...        ...               ...
# 0                               2.125461   0.431635         19.126117
# 42                              1.156012   0.541845          6.375372
# 64                              1.022446   0.540622          5.183714
# 2                               2.320873   0.995648         10.278054
# 19                              1.387134   0.455738         17.457795
#
#     num_crashes_last_month  diff_expected_crashes
# 60                       5              -7.363456
# 12                      17              -5.939424
# 51                       9              -5.031778
# 20                       2              -4.732870
# 7                        4              -3.477656
# ..                     ...                    ...
# 0                       24               4.873883
# 42                      12               5.624628
# 64                      11               5.816286
# 2                       18               7.721946
# 19                      26               8.542205
#
# [115 rows x 9 columns]

# %%
comparison = comparison.sort_values(by='diff_expected_crashes')

comparison.loc[comparison['diff_expected_crashes'].rank() <= 5, 'leaderboard'] = (
    comparison.loc[comparison['diff_expected_crashes'].rank() <= 5].apply(
        lambda row: f'{row.diff_expected_crashes:.0f} crashes'
        , axis=1
    )
)

comparison.loc[comparison['diff_expected_crashes'].rank(ascending=False) <= 5, 'leaderboard'] = (
    comparison.loc[comparison['diff_expected_crashes'].rank(ascending=False) <= 5].apply(
        lambda row: f'+{row.diff_expected_crashes:.0f} crashes'
        , axis=1
    )
)

# %%
comparison['street_name'] = comparison['fullname'].str.title()
comparison.loc[comparison.leaderboard.notnull(), ['street_name', 'leaderboard']]
# Out:
#         street_name leaderboard
# 60  S Sheridan Blvd  -7 crashes
# 12  N Colorado Blvd  -6 crashes
# 51      N Quebec St  -5 crashes
# 20    N Santa Fe Dr  -5 crashes
# 7           20Th St  -3 crashes
# 0      N Speer Blvd  +5 crashes
# 42         Blake St  +6 crashes
# 64       N Tower Rd  +6 crashes
# 2        Park Ave W  +8 crashes
# 19   S Federal Blvd  +9 crashes
