# %% [markdown]
# # Most Dangerous Streets - Crash Leaderboard
#
# Compare the most recent month to the all-time numbers to see which streets got safer.

# %%
import pytz
import folium
import pandas as pd
from datetime import datetime, timedelta

import os
os.chdir('..')
from scripts.crash_data_analysis import CrashDataAnalysis

# %%
cda = CrashDataAnalysis()

# %%
start_date = pytz.timezone('America/Denver').localize(datetime(2020,7,1))
end_date = cda.most_recent_crash_timestamp()

all_time = cda.street_metrics(start_date, end_date)

# %%
start_date = pytz.timezone('America/Denver').localize(datetime(2024,5,1))
end_date = pytz.timezone('America/Denver').localize(datetime(2024,6,1))

last_month = cda.street_metrics(start_date, end_date)

# %%
# A street must have at least 100 crashes all-time to be in the comparison
all_time = all_time[all_time.num_crashes >= 100].copy()

# %%
all_time
# Out:
#        gid      lrsroute                      fullname
# 2600  3900   SPEERN   BD                  N SPEER BLVD  \
# 3148  1452   ESPEERN  BD                  E SPEER BLVD
# 479   5587   PARK     AV                    PARK AVE W
# 1631  4229   22ND     ST                       22ND ST
# 3162  4225   20TH     ST                       20TH ST
# ...    ...           ...                           ...
# 268   1958   MARTINLUTBD  E MARTIN LUTHER KING JR BLVD
# 2598   291  35TH     AV1                    E 35TH AVE
# 1754  7579  WYALE    AV1                    W YALE AVE
# 671   7323  WLOUISIANAV1               W LOUISIANA AVE
# 3095  1661  HOLLY    ST1                    N HOLLY ST
#
#          street_name_no_cardinal  length_miles
# 2600                  SPEER BLVD      2.634723  \
# 3148                  SPEER BLVD      1.060124
# 479                   PARK AVE W      1.809664
# 1631                     22ND ST      1.079568
# 3162                     20TH ST      1.453330
# ...                          ...           ...
# 268   MARTIN LUTHER KING JR BLVD      3.328518
# 2598                    35TH AVE      4.421519
# 1754                    YALE AVE      3.004537
# 671                LOUISIANA AVE      3.003244
# 3095                    HOLLY ST      3.763453
#
#                                             street_line  num_crashes  num_sbi
# 2600  {"type":"MultiLineString","coordinates":[[[-10...          944       31  \
# 3148  {"type":"MultiLineString","coordinates":[[[-10...          289        8
# 479   {"type":"MultiLineString","coordinates":[[[-10...          492       20
# 1631  {"type":"MultiLineString","coordinates":[[[-10...          291        9
# 3162  {"type":"MultiLineString","coordinates":[[[-10...          389       11
# ...                                                 ...          ...      ...
# 268   {"type":"MultiLineString","coordinates":[[[-10...          135        4
# 2598  {"type":"MultiLineString","coordinates":[[[-10...          175        4
# 1754  {"type":"MultiLineString","coordinates":[[[-10...          109        9
# 671   {"type":"MultiLineString","coordinates":[[[-10...          103        2
# 3095  {"type":"MultiLineString","coordinates":[[[-10...          110        0
#
#       num_fatality  num_sbi_or_fatality  sum_bicycle_ind  sum_pedestrian_ind
# 2600             7                   38             15.0                27.0  \
# 3148             2                   10              5.0                 6.0
# 479              2                   22              6.0                19.0
# 1631             2                   11              4.0                15.0
# 3162             0                   11              8.0                26.0
# ...            ...                  ...              ...                 ...
# 268              1                    5              2.0                 2.0
# 2598             1                    5              1.0                 3.0
# 1754             1                   10              2.0                 2.0
# 671              0                    2              1.0                 3.0
# 3095             0                    0              2.0                 1.0
#
#       days_in_data  days_between_crashes  crashes_per_mile_per_week
# 2600          1485              1.573093                   1.688918  \
# 3148          1485              5.138408                   1.285029
# 479           1485              3.018293                   1.281559
# 1631          1485              5.103093                   1.270617
# 3162          1485              3.817481                   1.261703
# ...            ...                   ...                        ...
# 268           1485             11.000000                   0.191185
# 2598          1485              8.485714                   0.186568
# 1754          1485             13.623853                   0.171010
# 671           1485             14.417476                   0.161666
# 3095          1485             13.500000                   0.137777
#
#       pedestrian_ind_per_mile_per_year
# 2600                          2.520534
# 3148                          1.392062
# 479                           2.582376
# 1631                          3.417474
# 3162                          4.400205
# ...                                ...
# 268                           0.147789
# 2598                          0.166884
# 1754                          0.163725
# 671                           0.245694
# 3095                          0.065355
#
# [165 rows x 16 columns]

# %%
comparison = pd.merge(
    all_time
    , last_month
    , how='inner'
    , on=['gid', 'lrsroute', 'fullname', 'length_miles','street_line']
    , suffixes=['_all_time', '_last_month']
)

# %%
comparison['diff_pmpw'] = (
    comparison['crashes_per_mile_per_week_last_month']
    - comparison['crashes_per_mile_per_week_all_time']
)

# %%
comparison['expected_crashes'] = (
    comparison['length_miles']
    * comparison['crashes_per_mile_per_week_all_time']
    * (comparison['days_in_data_last_month'] / 7)
)

comparison['diff_expected_crashes'] = comparison['num_crashes_last_month'] - comparison['expected_crashes']

# %% [markdown]
# ## Difference in Crash Rate per Mile

# %%
this_map = folium.Map(prefer_canvas=True, tiles='CartoDB Positron')

good_streets = comparison.sort_values(by='diff_pmpw').head(5)['street_line']
bad_streets = comparison.sort_values(by='diff_pmpw').tail(5)['street_line']

for good_street in good_streets:
    folium.GeoJson(good_street, style_function=lambda x: {'color': 'green'}).add_to(this_map)

for bad_street in bad_streets:
    folium.GeoJson(bad_street, style_function=lambda x: {'color': 'red'}).add_to(this_map)
    
this_map.fit_bounds(this_map.get_bounds())
this_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c51b39d6fa2ca2299e0e4815c540c537 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c51b39d6fa2ca2299e0e4815c540c537&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c51b39d6fa2ca2299e0e4815c540c537 = L.map(
#                 &quot;map_c51b39d6fa2ca2299e0e4815c540c537&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1459fa1b15880662dcf0e68e1c2ffea3 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c51b39d6fa2ca2299e0e4815c540c537);
#
#
#         function geo_json_4e640c67458e2062fc20273a564dbf3c_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;};
#             }
#         }
#
#         function geo_json_4e640c67458e2062fc20273a564dbf3c_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_4e640c67458e2062fc20273a564dbf3c = L.geoJson(null, {
#                 onEachFeature: geo_json_4e640c67458e2062fc20273a564dbf3c_onEachFeature,
#
#                 style: geo_json_4e640c67458e2062fc20273a564dbf3c_styler,
#         });
#
#         function geo_json_4e640c67458e2062fc20273a564dbf3c_add (data) {
#             geo_json_4e640c67458e2062fc20273a564dbf3c
#                 .addData(data)
#                 .addTo(map_c51b39d6fa2ca2299e0e4815c540c537);
#         }
#             geo_json_4e640c67458e2062fc20273a564dbf3c_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-105.003224738, 39.748502998], [-105.003117893, 39.748662491], [-105.003068763, 39.748716611], [-105.002775361, 39.748841649], [-105.002611066, 39.748940476], [-105.002506339, 39.749039547], [-105.002211085, 39.749550288], [-105.001241161, 39.750286714], [-105.000025309, 39.751219404], [-104.998809248, 39.752176098], [-104.997624621, 39.753085216], [-104.996412226, 39.75401754], [-104.995147918, 39.754993552]]], &quot;type&quot;: &quot;MultiLineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_408b01bfcd9daed98d4076a0d4db7d0c_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;};
#             }
#         }
#
#         function geo_json_408b01bfcd9daed98d4076a0d4db7d0c_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_408b01bfcd9daed98d4076a0d4db7d0c = L.geoJson(null, {
#                 onEachFeature: geo_json_408b01bfcd9daed98d4076a0d4db7d0c_onEachFeature,
#
#                 style: geo_json_408b01bfcd9daed98d4076a0d4db7d0c_styler,
#         });
#
#         function geo_json_408b01bfcd9daed98d4076a0d4db7d0c_add (data) {
#             geo_json_408b01bfcd9daed98d4076a0d4db7d0c
#                 .addData(data)
#                 .addTo(map_c51b39d6fa2ca2299e0e4815c540c537);
#         }
#             geo_json_408b01bfcd9daed98d4076a0d4db7d0c_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-104.987415488, 39.727275836], [-104.986730187, 39.726912873], [-104.98617264, 39.726583064], [-104.985875639, 39.726359741], [-104.985645083, 39.726164849], [-104.985114781, 39.725637155], [-104.98488304, 39.725395494], [-104.983789953, 39.724255616], [-104.983629145, 39.724126225], [-104.983442053, 39.723945929], [-104.98293675, 39.723527457], [-104.98285098, 39.723467713], [-104.982381459, 39.723138957], [-104.981761264, 39.722754977], [-104.981236486, 39.722429181], [-104.980516522, 39.721977027], [-104.979926464, 39.721606557], [-104.979352338, 39.721245757], [-104.978749904, 39.720867326], [-104.978127857, 39.720498759], [-104.977546752, 39.720122823], [-104.97710517, 39.719867951], [-104.97672973, 39.719682346], [-104.976394023, 39.719531917], [-104.97607406, 39.719415537], [-104.97560858, 39.719267964], [-104.975220963, 39.719166375], [-104.974644981, 39.719028089], [-104.974054388, 39.718886292], [-104.973270995, 39.718706058], [-104.972886456, 39.718620882], [-104.972668555, 39.718572617], [-104.97232615, 39.71848735], [-104.972087532, 39.718427942], [-104.971744593, 39.718363502]]], &quot;type&quot;: &quot;MultiLineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_6d65722978b3a9a09be

# %%
comparison.sort_values(by='diff_pmpw')[[
    'gid'
    , 'fullname'
    , 'length_miles'
    , 'crashes_per_mile_per_week_all_time'
    , 'crashes_per_mile_per_week_last_month'
    , 'diff_pmpw'
    , 'num_crashes_all_time'
    , 'num_crashes_last_month'
    , 'expected_crashes'
    , 'diff_expected_crashes'
]]
# Out:
#      gid           fullname  length_miles  crashes_per_mile_per_week_all_time
# 10  3811           WAZEE ST      0.624810                            1.139202  \
# 1   1452       E SPEER BLVD      1.060124                            1.285029
# 4   4225            20TH ST      1.453330                            1.261703
# 25  2941         N TOWER RD      1.027545                            0.889964
# 44  4220            18TH ST      0.843447                            0.687415
# ..   ...                ...           ...                                 ...
# 43  1799     N JOSEPHINE ST      1.876373                            0.698389
# 34  4552       LEETSDALE DR      2.002250                            0.814572
# 35   747       E ALBROOK DR      1.031028                            0.772659
# 82  6862        MORRISON RD      1.486422                            0.494714
# 31  3393  N UNIVERSITY BLVD      0.662389                            0.832616
#
#     crashes_per_mile_per_week_last_month  diff_pmpw  num_crashes_all_time
# 10                              0.361400  -0.777801                   151  \
# 1                               0.639000  -0.646029                   289
# 4                               0.776859  -0.484844                   389
# 25                              0.439507  -0.450458                   194
# 44                              0.267719  -0.419696                   123
# ..                                   ...        ...                   ...
# 43                              1.203420   0.505031                   278
# 34                              1.353316   0.538744                   346
# 35                              1.314065   0.541407                   169
# 82                              1.063389   0.568675                   156
# 31                              1.704486   0.871871                   117
#
#     num_crashes_last_month  expected_crashes  diff_expected_crashes
# 10                       1          3.152189              -2.152189
# 1                        3          6.032997              -3.032997
# 4                        5          8.120539              -3.120539
# 25                       2          4.049832              -2.049832
# 44                       1          2.567677              -1.567677
# ..                     ...               ...                    ...
# 43                      10          5.803367               4.196633
# 34                      12          7.222896               4.777104
# 35                       6          3.527946               2.472054
# 82                       7          3.256566               3.743434
# 31                       5          2.442424               2.557576
#
# [161 rows x 10 columns]

# %% [markdown]
# ## Difference in Number of Expected Crashes

# %%
this_map = folium.Map(prefer_canvas=True, tiles='CartoDB Positron')

good_streets = comparison.sort_values(by='diff_expected_crashes').head(5)['street_line']
bad_streets = comparison.sort_values(by='diff_expected_crashes').tail(5)['street_line']

for good_street in good_streets:
    folium.GeoJson(good_street, style_function=lambda x: {'color': 'green'}).add_to(this_map)

for bad_street in bad_streets:
    folium.GeoJson(bad_street, style_function=lambda x: {'color': 'red'}).add_to(this_map)
    
this_map.fit_bounds(this_map.get_bounds())
this_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9e0c4954b2e806ed3c77fdb9e28cc16e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9e0c4954b2e806ed3c77fdb9e28cc16e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9e0c4954b2e806ed3c77fdb9e28cc16e = L.map(
#                 &quot;map_9e0c4954b2e806ed3c77fdb9e28cc16e&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc6adb532c85f4218049a0cec7019473 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9e0c4954b2e806ed3c77fdb9e28cc16e);
#
#
#         function geo_json_26856559068a7739aec92d84cd387e95_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;};
#             }
#         }
#
#         function geo_json_26856559068a7739aec92d84cd387e95_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_26856559068a7739aec92d84cd387e95 = L.geoJson(null, {
#                 onEachFeature: geo_json_26856559068a7739aec92d84cd387e95_onEachFeature,
#
#                 style: geo_json_26856559068a7739aec92d84cd387e95_styler,
#         });
#
#         function geo_json_26856559068a7739aec92d84cd387e95_add (data) {
#             geo_json_26856559068a7739aec92d84cd387e95
#                 .addData(data)
#                 .addTo(map_9e0c4954b2e806ed3c77fdb9e28cc16e);
#         }
#             geo_json_26856559068a7739aec92d84cd387e95_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-104.809797351, 39.783755499], [-104.809562794, 39.783806624], [-104.808238888, 39.783827728], [-104.80741563, 39.783811337], [-104.806225428, 39.783810106], [-104.80423265, 39.7838071], [-104.801715279, 39.783797432], [-104.799851029, 39.783791976], [-104.79796617, 39.783786433], [-104.796923745, 39.783783354], [-104.794652418, 39.783776611], [-104.794574267, 39.783776378], [-104.792182492, 39.783646525], [-104.791984142, 39.783645226], [-104.791380215, 39.783641272], [-104.791378224, 39.783641259], [-104.790970269, 39.783639713], [-104.790478104, 39.783637854], [-104.790033068, 39.783636169], [-104.789892997, 39.783637596], [-104.78950122, 39.783641581], [-104.789027458, 39.783647342], [-104.788616282, 39.783651754], [-104.787458933, 39.783643027], [-104.785988712, 39.783639297], [-104.784517254, 39.783637761], [-104.781698693, 39.783634768], [-104.777538488, 39.783626285], [-104.775574173, 39.78362223], [-104.774636128, 39.783619864], [-104.774473184, 39.783718623], [-104.774304739, 39.783619027], [-104.772727573, 39.783615025], [-104.772356681, 39.783612734], [-104.772121278, 39.783698079], [-104.771869369, 39.783626449], [-104.769929872, 39.783633924], [-104.769781684, 39.783712913], [-104.76962614, 39.783635091], [-104.769225778, 39.783636628], [-104.767761727, 39.783640998], [-104.767579572, 39.783641359], [-104.767420726, 39.783715749], [-104.767263397, 39.783641984], [-104.765982238, 39.783644514], [-104.765075142, 39.783648896], [-104.764901687, 39.783728236], [-104.764752484, 39.783649969], [-104.763433906, 39.783651921], [-104.763102008, 39.783652986], [-104.762348812, 39.783655395], [-104.76165376, 39.783654986], [-104.761335242, 39.783656938], [-104.761144455, 39.783728677], [-104.760955209, 39.783659894], [-104.759324459, 39.783675409], [-104.758752486, 39.783653973], [-104.758249561, 39.783602149], [-104.757881443, 39.783551696], [-104.757413108, 39.783458345], [-104.757206913, 39.783410879], [-104.757038748, 39.783367856], [-104.75683808, 39.783312032], [-104.756653734, 39.783256311], [-104.756491141, 39.783200727], [-104.756290524, 39.783140711], [-104.755984304, 39.78303648], [-104.75561512, 39.782910154], [-104.755409035, 39.782906452], [-104.755273221, 39.782777539], [-104.754731055, 39.782603644], [-104.753706735, 39.782255129], [-104.752876777, 39.781972282], [-104.752840951, 39.781960072], [-104.752204186, 39.781739902], [-104.751529486, 39.7815069], [-104.751265281, 39.781417092], [-104.751011914, 39.781331546], [-104.75077062, 39.781260765], [-104.750541437, 39.781202652], [-104.750121062, 39.781119318], [-104.749777752, 39.781075026], [-104.749537939, 39.781048239], [-104.749443294, 39.781039432], [-104.749252192, 39.781100804], [-104.749054893, 39.781021586], [-104.74812972, 39.781022559], [-104.746726377, 39.781025129], [-104.745812234, 39.781027313], [-104.743802742, 39.781030521], [-104.743491342, 39.781031665], [-104.743285951, 39.781036642], [-104.742

# %%
comparison.sort_values(by='diff_expected_crashes')[[
    'gid'
    , 'fullname'
    , 'length_miles'
    , 'crashes_per_mile_per_week_all_time'
    , 'crashes_per_mile_per_week_last_month'
    , 'diff_pmpw'
    , 'expected_crashes'
    , 'num_crashes_last_month'
    , 'diff_expected_crashes'
]]
# Out:
#       gid                 fullname  length_miles
# 98   1430  GREEN VALLEY RANCH BLVD      4.075550  \
# 109   920      N CENTRAL PARK BLVD      4.490628
# 107  1431  GREEN VALLEY RANCH BLVD      2.578838
# 21   7584           S FEDERAL BLVD      4.373528
# 120  2938               N TOWER RD      7.211247
# ..    ...                      ...           ...
# 11   5384             W COLFAX AVE      2.317662
# 34   4552             LEETSDALE DR      2.002250
# 63   2474              N QUEBEC ST      5.785164
# 26   4689           N FEDERAL BLVD      5.367276
# 5    1012             E COLFAX AVE      5.475202
#
#      crashes_per_mile_per_week_all_time  crashes_per_mile_per_week_last_month
# 98                             0.437197                              0.110810  \
# 109                            0.406233                              0.201136
# 107                            0.414929                              0.087561
# 21                             0.950623                              0.774454
# 120                            0.351677                              0.250505
# ..                                  ...                                   ...
# 11                             1.104387                              1.558857
# 34                             0.814572                              1.353316
# 63                             0.562218                              0.819672
# 26                             0.887910                              1.220058
# 5                              1.259551                              1.732150
#
#      diff_pmpw  expected_crashes  num_crashes_last_month
# 98   -0.326387          7.890909                       2  \
# 109  -0.205098          8.078788                       4
# 107  -0.327367          4.738721                       1
# 21   -0.176169         18.412121                      15
# 120  -0.101172         11.230976                       8
# ..         ...               ...                     ...
# 11    0.454470         11.335354                      16
# 34    0.538744          7.222896                      12
# 63    0.257453         14.404040                      21
# 26    0.332148         21.105051                      29
# 5     0.472599         30.540741                      42
#
#      diff_expected_crashes
# 98               -5.890909
# 109              -4.078788
# 107              -3.738721
# 21               -3.412121
# 120              -3.230976
# ..                     ...
# 11                4.664646
# 34                4.777104
# 63                6.595960
# 26                7.894949
# 5                11.459259
#
# [161 rows x 9 columns]

# %%
comparison = comparison.sort_values(by='diff_expected_crashes')

comparison.loc[comparison['diff_expected_crashes'].rank() <= 5, 'Leaderboard'] = (
    comparison.loc[comparison['diff_expected_crashes'].rank() <= 5].apply(
        lambda row: f'{row.diff_expected_crashes:.0f} crashes'
        , axis=1
    )
)

comparison.loc[comparison['diff_expected_crashes'].rank(ascending=False) <= 5, 'Leaderboard'] = (
    comparison.loc[comparison['diff_expected_crashes'].rank(ascending=False) <= 5].apply(
        lambda row: f'+{row.diff_expected_crashes:.0f} crashes'
        , axis=1
    )
)

# comparison['Expected Crashes'] = comparison.expected_c

# %%
comparison['street_name'] = comparison['fullname'].str.title()
comparison.loc[
    comparison.Leaderboard.notnull()
    , ['street_name', 'expected_crashes', 'num_crashes_last_month', 'Leaderboard']
].style.format('{:.1f}', subset='expected_crashes')
# Out:
# <style type="text/css">
# </style>
# <table id="T_8b80c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b80c_level0_col0" class="col_heading level0 col0" >street_name</th>
#       <th id="T_8b80c_level0_col1" class="col_heading level0 col1" >expected_crashes</th>
#       <th id="T_8b80c_level0_col2" class="col_heading level0 col2" >num_crashes_last_month</th>
#       <th id="T_8b80c_level0_col3" class="col_heading level0 col3" >Leaderboard</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b80c_level0_row0" class="row_heading level0 row0" >98</th>
#       <td id="T_8b80c_row0_col0" class="data row0 col0" >Green Valley Ranch Blvd</td>
#       <td id="T_8b80c_row0_col1" class="data row0 col1" >7.9</td>
#       <td id="T_8b80c_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_8b80c_row0_col3" class="data row0 col3" >-6 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_8b80c_level0_row1" class="row_heading level0 row1" >109</th>
#       <td id="T_8b80c_row1_col0" class="data row1 col0" >N Central Park Blvd</td>
#       <td id="T_8b80c_row1_col1" class="data row1 col1" >8.1</td>
#       <td id="T_8b80c_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_8b80c_row1_col3" class="data row1 col3" >-4 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_8b80c_level0_row2" class="row_heading level0 row2" >107</th>
#       <td id="T_8b80c_row2_col0" class="data row2 col0" >Green Valley Ranch Blvd</td>
#       <td id="T_8b80c_row2_col1" class="data row2 col1" >4.7</td>
#       <td id="T_8b80c_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_8b80c_row2_col3" class="data row2 col3" >-4 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_8b80c_level0_row3" class="row_heading level0 row3" >21</th>
#       <td id="T_8b80c_row3_col0" class="data row3 col0" >S Federal Blvd</td>
#       <td id="T_8b80c_row3_col1" class="data row3 col1" >18.4</td>
#       <td id="T_8b80c_row3_col2" class="data row3 col2" >15</td>
#       <td id="T_8b80c_row3_col3" class="data row3 col3" >-3 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_8b80c_level0_row4" class="row_heading level0 row4" >120</th>
#       <td id="T_8b80c_row4_col0" class="data row4 col0" >N Tower Rd</td>
#       <td id="T_8b80c_row4_col1" class="data row4 col1" >11.2</td>
#       <td id="T_8b80c_row4_col2" class="data row4 col2" >8</td>
#       <td id="T_8b80c_row4_col3" class="data row4 col3" >-3 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_8b80c_level0_row5" class="row_heading level0 row5" >11</th>
#       <td id="T_8b80c_row5_col0" class="data row5 col0" >W Colfax Ave</td>
#       <td id="T_8b80c_row5_col1" class="data row5 col1" >11.3</td>
#       <td id="T_8b80c_row5_col2" class="data row5 col2" >16</td>
#       <td id="T_8b80c_row5_col3" class="data row5 col3" >+5 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_8b80c_level0_row6" class="row_heading level0 row6" >34</th>
#       <td id="T_8b80c_row6_col0" class="data row6 col0" >Leetsdale Dr</td>
#       <td id="T_8b80c_row6_col1" class="data row6 col1" >7.2</td>
#       <td id="T_8b80c_row6_col2" class="data row6 col2" >12</td>
#       <td id="T_8b80c_row6_col3" class="data row6 col3" >+5 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_8b80c_level0_row7" class="row_heading level0 row7" >63</th>
#       <td id="T_8b80c_row7_col0" class="data row7 col0" >N Quebec St</td>
#       <td id="T_8b80c_row7_col1" class="data row7 col1" >14.4</td>
#       <td id="T_8b80c_row7_col2" class="data row7 col2" >21</td>
#       <td id="T_8b80c_row7_col3" class="data row7 col3" >+7 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_8b80c_level0_row8" class="row_heading level0 row8" >26</th>
#       <td id="T_8b80c_row8_col0" class="data row8 col0" >N Federal Blvd</td>
#       <td id="T_8b80c_row8_col1" class="data row8 col1" >21.1</td>
#       <td id="T_8b80c_row8_col2" class="data row8 col2" >29</td>
#       <td id="T_8b80c_row8_col3" class="data row8 col3" >+8 crashes</td>
#     </tr>
#     <tr>
#       <th id="T_8b80c_level0_row9" class="row_heading level0 row9" >5</th>
#       <td id="T_8b80c_row9_col0" class="data row9 col0" >E Colfax Ave</td>
#       <td id="T_8b80c_row9_col1" class="data row9 col1" >30.5</td>
#       <td id="T_8b80c_row9_col2" class="data row9 col2" >42</td>
#       <td id="T_8b80c_row9_col3" class="data row9 col3" >+11 crashes</td>
#     </tr>
#   </tbody>
# </table>
