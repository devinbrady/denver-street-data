# %% [markdown]
# # ArcGIS API output
#
# Look at the data returned by the API.

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/api_results.csv')

# %%
df[df.incident_id == 'DP201348']['reported_date']
# Out:
# 0    1356999540000
# Name: reported_date, dtype: int64
