# %% [markdown]
# Look at downloaded CSV files for the count of records by date.

# %%
import os
os.chdir('..')

import pandas as pd

# %%
df = pd.read_csv('data/crash_data_raw_20260421.csv', low_memory=False)

# %%
df['reported_date'] = pd.to_datetime(df['reported_date'])

# %%
df.groupby(df['reported_date'].dt.date).size().tail(10)
# Out:
# reported_date
# 2026-02-28    44
# 2026-03-01    52
# 2026-03-02    33
# 2026-03-03    57
# 2026-03-04    64
# 2026-03-05    58
# 2026-03-06    56
# 2026-03-07    48
# 2026-03-08    54
# 2026-03-09    37
# dtype: int64
