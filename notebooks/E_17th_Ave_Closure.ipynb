# %% [markdown]
# ## E 17th Ave Closure
#
# How has the closure of E 17th Ave at City Park impacted crash counts on parallel streets?

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib._color_data import BASE_COLORS, TABLEAU_COLORS, CSS4_COLORS, XKCD_COLORS
from datetime import datetime
import pytz

import os
os.chdir('..')

from scripts.crash_data_analysis import CrashDataAnalysis

# %%
cda = CrashDataAnalysis()
df = cda.crash_dataframe() # todo: make this a SQL query
# Out:
# Converting field "reported_date" to Denver time.

# %%
longitude_downing = -104.97336507173875
longitude_york = -104.95978236506068
longitude_colorado = -104.94071722366886
longitude_glencoe = -104.92584705683117

streets_in_analysis = [
    'E 13TH AVE'
    , 'E 14TH AVE'
    , 'E COLFAX AVE'
    , 'E 16TH AVE'
    , 'E 17TH AVE'
    , 'E 23RD AVE'
    , 'E 26TH AVE'
]

# %%
df['analysis_street'] = None

for s in streets_in_analysis:
    rows = (
        (df.incident_address.str.contains(s))
        & (df.geo_lon > longitude_york)
        & (df.geo_lon < longitude_colorado)
        & (df.reported_date >= '2015-01-01')
    )
    
    df.loc[rows, 'analysis_street'] = s

# %%
# df[df.analysis_street.notnull()]
df['one'] = 1

# %%
crash_counts = pd.pivot_table(
    data=df
#     , index=df.reported_date.dt.strftime('%Y-%m')
    , index=df.reported_date.dt.to_period('Q')
    , columns='analysis_street'
    , values='one'
    , aggfunc=sum
    , fill_value=0
)
# Out:
# /var/folders/4t/2xdd5b8965j2rjzd9rjml1xc0000gn/T/ipykernel_44515/3994784084.py:4: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   , index=df.reported_date.dt.to_period('Q')

# %%
crash_counts = crash_counts[streets_in_analysis].copy()
crash_counts
# Out:
# analysis_street  E 13TH AVE  E 14TH AVE  E COLFAX AVE  E 16TH AVE  E 17TH AVE
# reported_date
# 2015Q1                    5          12            25           2           8  \
# 2015Q2                   11          18            31           4           9
# 2015Q3                    7          15            33           5           7
# 2015Q4                   13          14            35           7          10
# 2016Q1                    7           8            26           2          10
# 2016Q2                   14          16            35           3          11
# 2016Q3                    6          21            24           7          10
# 2016Q4                   10          11            25           7          12
# 2017Q1                    7          17            26           2          10
# 2017Q2                    8          14            29           4          10
# 2017Q3                    8          19            29           5          13
# 2017Q4                   14          15            37           3           7
# 2018Q1                   11          13            40           0          13
# 2018Q2                   21          11            28           3           8
# 2018Q3                   10          14            36           1          11
# 2018Q4                   16          13            27           7           7
# 2019Q1                   12          13            24           2           5
# 2019Q2                    9          11            32           5           7
# 2019Q3                   10          10            34           6          15
# 2019Q4                    7          10            34           3          10
# 2020Q1                   10           7            24           4           5
# 2020Q2                    1           2            14           2           5
# 2020Q3                   11           6            22           1           5
# 2020Q4                    8           8            13           1           3
# 2021Q1                    6           5            18           1           3
# 2021Q2                   10           5            28           2           4
# 2021Q3                    8          11            30           2           3
# 2021Q4                    3          16            23           3           1
# 2022Q1                    8           5            13           7           1
# 2022Q2                    6           9            33           3           5
# 2022Q3                    7          20            19           2           4
# 2022Q4                    4          17            13           1           5
# 2023Q1                    4           8            27           2           7
# 2023Q2                    6           7            31           1           6
# 2023Q3                    6          11            23           3           4
# 2023Q4                    5           6            21           2           4
# 2024Q1                    7           2            23           2           6
# 2024Q2                   14           8            26           4           5
# 2024Q3                    1           6            17           2           5
# 2024Q4                    3           6            13           1           3
# 2025Q1                    6           7            16           3           5
# 2025Q2                    5          14             8           3           9
# 2025Q3                    2           3             6           1           3
#
# analysis_street  E 23RD AVE  E 26TH AVE
# reported_date
# 2015Q1                    1           2
# 2015Q2                    3           3
# 2015Q3                    3           0
# 2015Q4                    4           3
# 2016Q1                    6           1
# 2016Q2                    3           2
# 2016Q3                    2           6
# 2016Q4                    0           1
# 2017Q1                    5           3
# 2017Q2                    0           0
# 2017Q3                    4           5
# 2017Q4                    2           3
# 2018Q1                    1           4
# 2018Q2                    5           5
# 2018Q3                    3           4
# 2018Q4                    4           2
# 2019Q1                    4           3
# 2019Q2                    2           0
# 2019Q3                    7           5
# 2019Q4                    2           6
# 2020Q1                    0           2
# 2020Q2                    1           1
# 2020Q3                    1           2
# 2020Q4                    1           1
# 2021Q1                    2           2
# 2021Q2                    3           3
# 2021Q3                    3           5
# 2021Q4                    1           5
# 2022Q1                    1           2
# 2022Q2                    4           3
# 2022Q3                    1           1
# 2022Q4                    3           1
# 2023Q1                    3           0
# 2023Q2                    3           2
# 2023Q3                    2           0
# 2023Q4                    2           2
# 2024Q1                    1           1
# 2024Q2                    3           4
# 2024Q3                    1           0
# 2024Q4                    1           1
# 2025Q1                    3           3
# 2025Q2                    2           2
# 2025Q3                    0           0

# %%
fig, ax = plt.subplots(nrows=len(streets_in_analysis), ncols=1, figsize=(15,20))

for idx, s in enumerate(streets_in_analysis[::-1]):
    crash_counts[s].plot.bar(ax=ax[idx])
    ax[idx].set_ylabel(s)
    ax[idx].set_xticks([])
    ax[idx].set_xlabel('')
    
# ax[6].set_xticks(['2015-01', '2016-01'])
