# %% [markdown]
# # Vehicle Type
#
# What sort of vehicles are involved in these crashes?

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib._color_data import BASE_COLORS, TABLEAU_COLORS, CSS4_COLORS, XKCD_COLORS
from crash_data_analysis import CrashDataAnalysis

# %%
cda = CrashDataAnalysis()
df = cda.crash_dataframe(verbose=True, all_columns=True)
# Out:
# Reading file: data/denver_crashes_2023_01_19__14_31.csv
# Max timestamp: Wed Jan 18, 6:48 PM (0.86 days ago)
# Deadly crashes this year: 3

# %%
df.TU1_VEHICLE_TYPE.unique()
# Out:
# array(['PASSENGER CAR/VAN', 'SUV', '  ', 'HIT AND RUN UNKNOWN',
#        'PICKUP TRUCK/UTILITY VAN', 'NON-SCHOOL BUS',
#        'PICKUP TRUCK/UTILITY VAN WITH TRAILIER', 'VEHICLE OVER 10000 LBS',
#        'OTHER', 'BICYCLE', 'MOTOR HOME', 'TRANSIT BUS', 'SCHOOL BUS',
#        'MOTORCYCLE', 'MOTORIZED BICYCLE',
#        'PASSENGER CAR/VAN WITH TRAILER', 'SUV WITH TRAILER',
#        'FARM EQUIPMENT', 'LIGHT RAIL', 'UNDER INVESTIGATION', 'UNK', '0',
#        'Passenger Car/Passenger Van', 'Pickup Truck/Utility Van',
#        'Medium/Heavy Trucks GVWR/GCWR between 10,001 and 16,000', nan,
#        'Motorcycle', 'Unknown (Hit and Run Only)', 'Transit Bus',
#        'Medium/Heavy Trucks GVWR/GCWR 16,001 and over',
#        'Other Vehicle Type (Describe in Narative)',
#        'School Bus (all school buses)', 'Autocycle',
#        'Working Vehicle/Equipment', 'Motor Home',
#        'Non-School Bus (9 occupants or more including driver) in commerce',
#        'Low Speed Vehicle', 'Off Highway Vehicle/ATV', 'Farm Equipment'],
#       dtype=object)

# %%
df.TU1_VEHICLE_MOVEMENT.unique()
# Out:
# array(['GOING STRAIGHT', 'MAKING LEFT TURN', 'MAKING U-TURN', '  ',
#        'ENTERING/LEAVING PARKED POSITION', 'OTHER', 'BACKING', 'SLOWING',
#        'MAKING RIGHT TURN', 'CHANGING LANES', 'STOPPED IN TRAFFIC',
#        'PASSING', 'SPUN OUT OF CONTROL', 'WEAVING', 'PARKED',
#        'AVOIDING OBJECT IN ROADWAY', 'DROVE WRONG WAY',
#        'UNDER INVESTIGATION', '021', '18', '00', 'Going Straight',
#        'Making Left Turn', 'Changing Lanes',
#        'Other (Describe in Narrative)', nan,
#        'Entering/Leaving Parked Position', 'Making Right Turn', 'Backing',
#        'Traveled Wrong Way', 'Entering Traffic Way/Merge',
#        'Making U-Turn', 'Slowing', 'Weaving', 'Parked',
#        'Stopped in Traffic', 'Negotiating a Curve', 'Out of Control',
#        'Swerve/Avoidance', 'Passing'], dtype=object)

# %%
# df['at_fault_vehicle'] = df['TU1_VEHICLE_TYPE']

# otherize = ['  ', '0', 'UNK']
# for v in otherize:
#     df.loc[df.TU1_VEHICLE_TYPE == v, 'at_fault_vehicle'] = 'Other'

# %%
df['TU1_VEHICLE_TYPE_UPPER'] = df['TU1_VEHICLE_TYPE'].str.upper()

vehicle_type_mapping = {
    '  ': 'Other'
    , '0': 'Other'
    , 'UNK': 'Other'
    , 'OTHER VEHICLE TYPE (DESCRIBE IN NARATIVE)': 'Other'
    , 'OTHER': 'Other'
    , 'SUV WITH TRAILER': 'SUV'
    , 'PASSENGER CAR/VAN': 'Passenger Car/Van'
    , 'PASSENGER CAR/VAN WITH TRAILER': 'Passenger Car/Van'
    , 'PASSENGER CAR/PASSENGER VAN': 'Passenger Car/Van'
    , 'SCHOOL BUS': 'Bus'
    , 'SCHOOL BUS (ALL SCHOOL BUSES)': 'Bus'
    , 'TRANSIT BUS': 'Bus'
    , 'HIT AND RUN UNKNOWN': 'Unknown (Hit and Run Only)'
    , 'PICKUP TRUCK/UTILITY VAN': 'Pickup Truck'
    , 'PICKUP TRUCK/UTILITY VAN WITH TRAILIER': 'Pickup Truck'
    , 'VEHICLE OVER 10000 LBS': 'Semi Truck'
    , 'MOTORCYCLE': 'Motorcycle'
    , 'BICYCLE': 'Bicycle'
    , 'UNDER INVESTIGATION': 'Under Investigation'
    , 'NON-SCHOOL BUS': 'Bus'
    , 'NON-SCHOOL BUS (9 OCCUPANTS OR MORE INCLUDING DRIVER) IN COMMERCE': 'Bus'
    , 'MEDIUM/HEAVY TRUCKS GVWR/GCWR 16,001 AND OVER': 'Semi Truck'
    , 'MEDIUM/HEAVY TRUCKS GVWR/GCWR BETWEEN 10,001 AND 16,000': 'Semi Truck'
    , 'OFF HIGHWAY VEHICLE/ATV': 'Other'
    , 'MOTOR HOME': 'Other'
    , 'MOTORIZED BICYCLE': 'Motorcycle'
    , 'FARM EQUIPMENT': 'Other'
    , 'LOW SPEED VEHICLE': 'Other'
    , 'AUTOCYCLE': 'Motorcycle'
    , 'WORKING VEHICLE/EQUIPMENT': 'Other'
    , 'LIGHT RAIL': 'Other'
}

df['at_fault_vehicle'] = df['TU1_VEHICLE_TYPE_UPPER'].map(vehicle_type_mapping).fillna(df['TU1_VEHICLE_TYPE'])

# %%
df.groupby('TU1_VEHICLE_TYPE_UPPER').size()
# Out:
# TU1_VEHICLE_TYPE_UPPER
#                                                                       2132
# 0                                                                        1
# AUTOCYCLE                                                               29
# BICYCLE                                                               1129
# FARM EQUIPMENT                                                          24
# HIT AND RUN UNKNOWN                                                  14704
# LIGHT RAIL                                                              27
# LOW SPEED VEHICLE                                                        8
# MEDIUM/HEAVY TRUCKS GVWR/GCWR 16,001 AND OVER                          411
# MEDIUM/HEAVY TRUCKS GVWR/GCWR BETWEEN 10,001 AND 16,000                210
# MOTOR HOME                                                             174
# MOTORCYCLE                                                            1461
# MOTORIZED BICYCLE                                                       92
# NON-SCHOOL BUS                                                         454
# NON-SCHOOL BUS (9 OCCUPANTS OR MORE INCLUDING DRIVER) IN COMMERCE       25
# OFF HIGHWAY VEHICLE/ATV                                                  5
# OTHER                                                                 8118
# OTHER VEHICLE TYPE (DESCRIBE IN NARATIVE)                               84
# PASSENGER CAR/PASSENGER VAN                                           9422
# PASSENGER CAR/VAN                                                    96848
# PASSENGER CAR/VAN WITH TRAILER                                         361
# PICKUP TRUCK/UTILITY VAN                                             24532
# PICKUP TRUCK/UTILITY VAN WITH TRAILIER                                4680
# SCHOOL BUS                                                             277
# SCHOOL BUS (ALL SCHOOL BUSES)                                           33
# SUV                                                                  47699
# SUV WITH TRAILER                                                       178
# TRANSIT BUS                                                            983
# UNDER INVESTIGATION                                                    717
# UNK                                                                      1
# UNKNOWN (HIT AND RUN ONLY)                                            1555
# VEHICLE OVER 10000 LBS                                                6323
# WORKING VEHICLE/EQUIPMENT                                               48
# dtype: int64

# %%
df.groupby('at_fault_vehicle').size().sort_values(ascending=False)
# Out:
# at_fault_vehicle
# Passenger Car/Van             106631
# SUV                            47877
# Pickup Truck                   29212
# Unknown (Hit and Run Only)     16259
# Other                          10622
# Semi Truck                      6944
# Bus                             1772
# Motorcycle                      1582
# Bicycle                         1129
# Under Investigation              717
# dtype: int64

# %%
# pd.pivot_table(
#     data=df
#     , values='one'
#     , index=['at_fault_vehicle', 'TU1_VEHICLE_TYPE_UPPER']
#     , columns='crash_year'
#     , aggfunc='sum'
#     , fill_value=0
# )

# %%
at_fault_vehicle_pivot = pd.pivot_table(
    data=df
    , values='one'
    , index='at_fault_vehicle'
    , columns='crash_year'
    , aggfunc='sum'
    , fill_value=0
)

at_fault_vehicle_pivot.drop('Under Investigation', inplace=True)
at_fault_vehicle_pivot
# Out:
# crash_year                   2013   2014   2015   2016   2017   2018   2019  \
# at_fault_vehicle
# Bicycle                       175    158    148    135    145    129    112
# Bus                           202    209    196    220    222    239    199
# Motorcycle                    158    152    167    178    165    154    138
# Other                         915    870    806    885   1226   1202   2436
# Passenger Car/Van           11237  11776  12655  12678  12829  12223  10734
# Pickup Truck                 2745   2898   3179   3315   3298   3444   3091
# SUV                          3993   4636   5217   5330   5456   5573   5521
# Semi Truck                    642    722    742    806    760    841    865
# Unknown (Hit and Run Only)   1550   1687   1682   1887   1792   1736   1745
#
# crash_year                  2020  2021  2022  2023
# at_fault_vehicle
# Bicycle                       72    54     1     0
# Bus                           90    89   104     2
# Motorcycle                   134   177   158     1
# Other                        791   828   658     5
# Passenger Car/Van           6839  7766  7592   302
# Pickup Truck                2346  2576  2246    74
# SUV                         3739  4459  3788   165
# Semi Truck                   543   552   453    18
# Unknown (Hit and Run Only)  1338  1568  1238    36

# %%
at_fault_vehicle_perc = at_fault_vehicle_pivot / at_fault_vehicle_pivot.sum(axis=0)
at_fault_vehicle_perc.style.format('{:.1%}').background_gradient()
# Out:
# <style type="text/css">
# #T_1e064_row0_col0, #T_1e064_row0_col1, #T_1e064_row0_col2, #T_1e064_row0_col3, #T_1e064_row0_col4, #T_1e064_row0_col5, #T_1e064_row0_col6, #T_1e064_row0_col7, #T_1e064_row0_col8, #T_1e064_row0_col9, #T_1e064_row0_col10, #T_1e064_row1_col2, #T_1e064_row1_col7, #T_1e064_row2_col0, #T_1e064_row2_col1, #T_1e064_row2_col2, #T_1e064_row2_col3, #T_1e064_row2_col4, #T_1e064_row2_col5, #T_1e064_row2_col6, #T_1e064_row2_col10 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_1e064_row1_col0, #T_1e064_row1_col1, #T_1e064_row1_col3, #T_1e064_row1_col4, #T_1e064_row1_col8, #T_1e064_row1_col10 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_1e064_row1_col5, #T_1e064_row1_col6, #T_1e064_row2_col7 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_1e064_row1_col9, #T_1e064_row2_col8, #T_1e064_row3_col10 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_1e064_row2_col9 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_1e064_row3_col0, #T_1e064_row7_col7 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_1e064_row3_col1, #T_1e064_row3_col3, #T_1e064_row7_col5, #T_1e064_row7_col9, #T_1e064_row7_col10 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_1e064_row3_col2, #T_1e064_row7_col3 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_1e064_row3_col4, #T_1e064_row3_col5, #T_1e064_row3_col9 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_1e064_row3_col6 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_1e064_row3_col7 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_1e064_row3_col8 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_1e064_row4_col0, #T_1e064_row4_col1, #T_1e064_row4_col2, #T_1e064_row4_col3, #T_1e064_row4_col4, #T_1e064_row4_col5, #T_1e064_row4_col6, #T_1e064_row4_col7, #T_1e064_row4_col8, #T_1e064_row4_col9, #T_1e064_row4_col10 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_1e064_row5_col0 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_1e064_row5_col1 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_1e064_row5_col2, #T_1e064_row5_col10 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_1e064_row5_col3 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_1e064_row5_col4 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_1e064_row5_col5 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_1e064_row5_col6 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_1e064_row5_col7 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_1e064_row5_col8 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_1e064_row5_col9 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_1e064_row6_col0 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_1e064_row6_col1 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_1e064_row6_col2 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_1e064_row6_col3 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_1e064_row6_col4 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_1e064_row6_col5 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_1e064_row6_col6 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_1e064_row6_col7 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_1e064_row6_col8 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_1e064_row6_col9 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_1e064_row6_col10 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_1e064_row7_col0, #T_1e064_row7_col1, #T_1e064_row7_col2, #T_1e064_row7_col4 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_1e064_row7_col6 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_1e064_row7_col8 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_1e064_row8_col0 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_1e064_row8_col1, #T_1e064_row8_col4 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_1e064_row8_col2 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_1e064_row8_col3 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_1e064_row8_col5 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_1e064_row8_col6 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_1e064_row8_col7 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_1e064_row8_col8 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_1e064_row8_col9 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_1e064_row8_col10 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# </style>
# <table id="T_1e064_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >crash_year</th>
#       <th class="col_heading level0 col0" >2013</th>
#       <th class="col_heading level0 col1" >2014</th>
#       <th class="col_heading level0 col2" >2015</th>
#       <th class="col_heading level0 col3" >2016</th>
#       <th class="col_heading level0 col4" >2017</th>
#       <th class="col_heading level0 col5" >2018</th>
#       <th class="col_heading level0 col6" >2019</th>
#       <th class="col_heading level0 col7" >2020</th>
#       <th class="col_heading level0 col8" >2021</th>
#       <th class="col_heading level0 col9" >2022</th>
#       <th class="col_heading level0 col10" >2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >at_fault_vehicle</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e064_level0_row0" class="row_heading level0 row0" >Bicycle</th>
#       <td id="T_1e064_row0_col0" class="data row0 col0" >0.8%</td>
#       <td id="T_1e064_row0_col1" class="data row0 col1" >0.7%</td>
#       <td id="T_1e064_row0_col2" class="data row0 col2" >0.6%</td>
#       <td id="T_1e064_row0_col3" class="data row0 col3" >0.5%</td>
#       <td id="T_1e064_row0_col4" class="data row0 col4" >0.6%</td>
#       <td id="T_1e064_row0_col5" class="data row0 col5" >0.5%</td>
#       <td id="T_1e064_row0_col6" class="data row0 col6" >0.5%</td>
#       <td id="T_1e064_row0_col7" class="data row0 col7" >0.5%</td>
#       <td id="T_1e064_row0_col8" class="data row0 col8" >0.3%</td>
#       <td id="T_1e064_row0_col9" class="data row0 col9" >0.0%</td>
#       <td id="T_1e064_row0_col10" class="data row0 col10" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_1e064_level0_row1" class="row_heading level0 row1" >Bus</th>
#       <td id="T_1e064_row1_col0" class="data row1 col0" >0.9%</td>
#       <td id="T_1e064_row1_col1" class="data row1 col1" >0.9%</td>
#       <td id="T_1e064_row1_col2" class="data row1 col2" >0.8%</td>
#       <td id="T_1e064_row1_col3" class="data row1 col3" >0.9%</td>
#       <td id="T_1e064_row1_col4" class="data row1 col4" >0.9%</td>
#       <td id="T_1e064_row1_col5" class="data row1 col5" >0.9%</td>
#       <td id="T_1e064_row1_col6" class="data row1 col6" >0.8%</td>
#       <td id="T_1e064_row1_col7" class="data row1 col7" >0.6%</td>
#       <td id="T_1e064_row1_col8" class="data row1 col8" >0.5%</td>
#       <td id="T_1e064_row1_col9" class="data row1 col9" >0.6%</td>
#       <td id="T_1e064_row1_col10" class="data row1 col10" >0.3%</td>
#     </tr>
#     <tr>
#       <th id="T_1e064_level0_row2" class="row_heading level0 row2" >Motorcycle</th>
#       <td id="T_1e064_row2_col0" class="data row2 col0" >0.7%</td>
#       <td id="T_1e064_row2_col1" class="data row2 col1" >0.7%</td>
#       <td id="T_1e064_row2_col2" class="data row2 col2" >0.7%</td>
#       <td id="T_1e064_row2_col3" class="data row2 col3" >0.7%</td>
#       <td id="T_1e064_row2_col4" class="data row2 col4" >0.6%</td>
#       <td id="T_1e064_row2_col5" class="data row2 col5" >0.6%</td>
#       <td id="T_1e064_row2_col6" class="data row2 col6" >0.6%</td>
#       <td id="T_1e064_row2_col7" class="data row2 col7" >0.8%</td>
#       <td id="T_1e064_row2_col8" class="data row2 col8" >1.0%</td>
#       <t

# %%
# at_fault_vehicle_perc.transpose().plot(kind='bar', stacked=True)

# %% [markdown]
# ## Conclusion
#
# This data does not appear to be populating correctly in 2022 :(

# %%
df[df.incident_id == 2022165626].squeeze()
# Out:
# shape                            <geoprocessing describe geometry object object...
# object_id                                                                      843
# incident_id                                                             2022165626
# offense_id                                                         202216562654410
# offense_code                                                                  5441
# offense_code_extension                                                           0
# top_traffic_accident_offense                        TRAF - ACCIDENT
# first_occurrence_date                                          2022-04-04 15:00:00
# last_occurrence_date                                           2022-04-04 15:00:00
# reported_date                                            2022-04-04 15:16:00-06:00
# incident_address                                         N GAYLORD ST / E 18TH AVE
# geo_x                                                                    3151566.0
# geo_y                                                                    1696624.0
# geo_lon                                                                -104.961005
# geo_lat                                                                  39.744803
# district_id                                                                 6
# precinct_id                                                                  622.0
# neighborhood_id                                                     City Park West
# bicycle_ind                                                                    0.0
# pedestrian_ind                                                                 0.0
# HARMFUL_EVENT_SEQ_1                                                  Front to Side
# HARMFUL_EVENT_SEQ_2                                                            NaN
# HARMFUL_EVENT_SEQ_MOST                                               Front to Side
# road_location                                                           On Roadway
# ROAD_DESCRIPTION                                                   At Intersection
# ROAD_CONTOUR                                                      Straight - Level
# ROAD_CONDITION                                                                 Dry
# LIGHT_CONDITION                                                           Daylight
# TU1_VEHICLE_TYPE                                       Passenger Car/Passenger Van
# TU1_TRAVEL_DIRECTION                                                         North
# TU1_VEHICLE_MOVEMENT                                                Going Straight
# TU1_DRIVER_ACTION                                              Failed to Yield ROW
# TU1_DRIVER_HUMANCONTRIBFACTOR                            Distracted/Other Interior
# TU1_PEDESTRIAN_ACTION                                                          NaN
# TU2_VEHICLE_TYPE                                                               SUV
# TU2_TRAVEL_DIRECTION                                                          West
# TU2_VEHICLE_MOVEMENT                                                Going Straight
# TU2_DRIVER_ACTION                                           No Contributing Action
# TU2_DRIVER_HUMANCONTRIBFACTOR                      No Apparent Contributing Factor
# TU2_PEDESTRIAN_ACTION                                                          NaN
# SERIOUSLY_INJURED                                                              0.0
# FATALITIES                                                                     0.0
# FATALITY_MODE_1                                                                NaN
# FATALITY_MODE_2                                                                NaN
# SERIOUSLY_INJURED_MODE_1                                                       NaN
# SERIOUSLY_INJURED_MODE_2                                                       NaN
# POINT_X                                                                        NaN
# POINT_Y                                                                        NaN
# sbi                                                                          False
# fatality                                                                     False
# sbi_or_fatality                                                              False
# crash_date                                                              2022-04-04
# crash_date_str                                                      2022-04-04 Mon
# crash_time_str                                                  Mon Apr 4, 3:16 PM
# crash_year                                                                    2022
# crash_day_of_year                                                               94
# one                                                                              1
# TU1_VEHICLE_TYPE_UPPER                                 PASSENGER CAR/PASSENGER VAN
# at_fault_vehicle                                                 Passenger Car/Van
# Name: 4768, dtype: object
